# %% [markdown]
# # 00 Comparing subjects I have data for vs those in Randy's Database

# %%
# install required packages - commented out so it doesn't install every time
#%conda install -n Lauren openpyxl numpy pandas statsmodels plotnine matplotlib scikit-learn scipy mizani nbconvert pandoc pyreadstat kmodes seaborn

# import required packages
import openpyxl; 
import datetime;
import numpy as np;
import pandas as pd;
import statsmodels as sm;
import statsmodels.formula.api as smf;
import plotnine as p9;
import matplotlib;
#import sklearn;
import scipy;
from scipy.stats import linregress;
from scipy.stats import pearsonr;
import itertools
from sklearn import preprocessing 
import inspect
import pickle

data_folder_loc = "//admsyn/Primary/ADM/CustomerStudies/Rockefeller/Riluzole_Biomarkers/"
code_folder_loc = "//admsyn/homes/@DH-ADMDX/0/lauren.koenig-1606/code/Riluzole FDG/"

# %%
# read in data
all_data, all_data_age_correct = pd.read_pickle(code_folder_loc + '/output/02_data.pkl')

# %%
# define biomarker groups
FDG_columns = ['AC_gm','Avg_Hip','R_Hip', 'L_Hip', 'Avg_MedOrbFrontal', 'Avg_PCC', 'FRONTAL_gm', 'MTL_gm',  'Par_gm', 'PostCing_gm', 'Precun_gm', 'Temp', 'Temp_gm', 'CV1']

plasma_columns = [ 'Ab40', 'Ab42', 'Ab42_40', 'GFAP','NFL',  'pTau181', 'pTau217',  'pTau231', 'pTau181_Ab42']
cog_columns = ['Screening_MMSE', 'adascogtotal', 'bvrt', 'dstotal','tma','tmb',  'cowattotal', 'cdrtotal', 'cdrsum', 'adltotal', 'npitotal', 'gds']
FDG_columns_pons = ['Temp_gm_ponsref', 'MTL_gm_ponsref', 'PostCing_gm_ponsref', 'Par_gm_ponsref', 'Precun_gm_ponsref', 'AC_gm_ponsref']
FDG_columns_para2 = ['Temp_gm_refpara2', 'MTL_gm_refpara2', 'PostCing_gm_refpara2', 'Par_gm_refpara2', 'Precun_gm_refpara2', 'AC_gm_refpara2', 'Avg_PCC_refpara2']
vol_columns = ['VOL_Precun_Lz', 'VOL_Precun_Rz', 'VOL_InfPar_Lz', 'VOL_InfPar_Rz', 'VOL_Hip_Lz', 'VOL_Hip_Rz', 'VOL_TotalGrayz', 'VOL_Inf_Mid_Fus_Temp_Lz', 
'VOL_Inf_Mid_Fus_Temp_Rz','VOL__MidFront_Lz', 'VOL_MidFront_Rz']

# %% [markdown]
# # all imaging data

# %%
randy_db = pd.read_excel(data_folder_loc + "original/discrete/Rockefeller_Database__Ver27__090920.xlsx", sheet_name='RKF Database', skiprows=13)

# %%
randy_db['FDG_output'] = randy_db['Grey matter'].notna()

randy_db['FS_output'] = randy_db['AparcPl_meancurv_R_TRANSVTEMP'].replace('pending', np.nan).astype('float64').notna()
randy_db['FS_pending'] = randy_db['AparcPl_meancurv_R_TRANSVTEMP'].isin(['pending'])

randy_db['SPM_output'] = randy_db['Total'].replace('pending?', np.nan).notna()
randy_db['SPM_pending'] = randy_db['AparcPl_meancurv_R_TRANSVTEMP'].isin(['pending?'])


randy_db['PredictedClass_output'] = randy_db['PredictedClass:'].notna()


randy_db['any_mri_output'] = randy_db[[ 'FS_output', 'SPM_output', 'PredictedClass_output']].any(axis = 1)

# %%
randy_db.columns[0:100]
# Out:
# Index(['INDEX-2', 'ProcDate', 'FDG multiframe?', 'INDEX-1', 'FDG Visit',
#        'Completed Protocol? (FDG)', 'Completed Protocol? (MRI)', 'Unnamed: 7',
#        'Subject', 'AGE', 'Gender', 'Visit (ALPHA) FDG', 'Visit (ALPHA)  MRI',
#        'Visit (ADM)', 'Image source', 'Unnamed: 15',
#        'FDG Visit Date (from DICOM)', 'Unnamed: 17', 'FileName:', 'CV1:',
#        'CV2:', 'CV3:', 'CV4:', 'CV5:', 'P_NL:', 'P_MA:', 'P_AD:', 'P_SAD:',
#        'P_FTD:', 'P_LBD:', 'P_SD:', 'PredictedClass:', 'Unnamed: 32',
#        'FileName:.1', 'CV1:.1', 'P_1.1:', 'P_1.2:', 'P_2.1:', 'P_2.2:',
#        'P_4.1:', 'P_6.1:', 'P_6.2:', 'P_7.1:', 'P_8.1:', 'P_8.3:',
#        'PredictedClass:.1', 'Unnamed: 46', 'LPT Source', 'x', 'Grey matter',
#        'Whole Brain Without Ventricle', 'R Occipital Lobe', 'L Occipital Lobe',
#        'R Inferior Parietal Lobe', 'L Inferior Parietal Lobe', 'R MFG',
#        'L MFG', 'R Prefrontal', 'L Prefrontal', 'R Lateral Temporal Lobe',
#        'L Lateral Temporal Lobe', 'R MTL', 'L MTL', 'R Orbital Frontal',
#        'L Orbital Frontal', 'R Anterior Putamen', 'L Anterior Putamen',
#        'R HIP', 'L HIP', 'Pons', 'R PCC', 'L PCC', 'R STG', 'L STG',
#        'R Thalamus', 'L Thalamus', 'R Amy', 'L Amy', 'Cerebellum',
#        'R Visual Cortex', 'L Visual Cortex', 'Unnamed: 81', 'Grey matter.1',
#        'Whole Brain Without Ventricle.1', 'R Occipital Lobe.1',
#        'L Occipital Lobe.1', 'R Inferior Parietal Lobe.1',
#        'L Inferior Parietal Lobe.1', 'R MFG.1', 'L MFG.1', 'R Prefrontal.1',
#        'L Prefrontal.1', 'R Lateral Temporal Lobe.1',
#        'L Lateral Temporal Lobe.1', 'R MTL.1', 'L MTL.1',
#        'R Orbital Frontal.1', 'L Orbital Frontal.1', 'R Anterior Putamen.1',
#        'L Anterior Putamen.1'],
#       dtype='object')

# %%
randy_db['FileName:']
# Out:
# 0                                                    NaN
# 1      n2a_sUR_i_n2a_rADNI_APE_792_201A__static-FDG__...
# 2                                                    NaN
# 3      n2a_sUR_i_n2a_rADNI_APE_792_201B__static-FDG__...
# 4                                                    NaN
#                              ...
# 330                                                  NaN
# 331                                                  NaN
# 332                                                  NaN
# 333                                                  NaN
# 334                                                  NaN
# Name: FileName:, Length: 335, dtype: object

# %%
randy_db['PredictedClass:'].isna().value_counts()
# Out:
# True     236
# False     99
# Name: PredictedClass:, dtype: int64

# %%
randy_db['FS_output'].value_counts()
# Out:
# False    260
# True      75
# Name: FS_output, dtype: int64

# %%
randy_db[['Completed Protocol? (FDG)','FDG_output']].value_counts()
# Out:
# Completed Protocol? (FDG)  FDG_output
# Y                          True          84
# X                          False         43
# N                          True          15
#                            False          1
# dtype: int64

# %%
randy_db.loc[randy_db['Completed Protocol? (FDG)'].isin(['N']) & (randy_db['FDG_output']==True), 
             [
                 
                  'Subject', 'AGE', 'Gender', 'Visit (ADM)',       
          
        'FDG Visit', 'FDG Visit Date (from DICOM)', 'Unnamed: 17',    
        #'FDG multiframe?',  'Image source',  'ProcDate',  
       'Completed Protocol? (FDG)',
        'LPT Source', 'FDG_output',  
             ]
             ]
# Out:
#          Subject  AGE Gender Visit (ADM)     FDG Visit  \
# 21   RKF-APE-009   75      M         m00  Visit-1 only
# 61   RKF-APE-021  UNK      O         m00  Visit-1 only
# 65   RKF-APE-022  UNK      O         m00  Visit-1 only
# 69   RKF-APE-023  UNK      O         m00  Visit-1 only
# 97   RKF-APE-035  UNK      O         m00  Visit-1 only
# 107  RKF-APE-039  UNK      O         m00  Visit-1 only
# 111  RKF-APE-040  UNK      O         m00  Visit-1 only
# 156  RKF-APE-060  UNK      O         m00  Visit-1 only
# 166  RKF-APE-065   81      M         m00  Visit-1 only
# 176  RKF-APE-071   69      M         m00  Visit-1 only
# 200  RKF-RIL-005  UNK      O         NaN  Visit-1 only
# 240  RKF-RIL-013   70      M         m00  Visit-1 only
# 257  RKF-RIL-017   76      F         m00  Visit-1 only
# 279  RKF-RIL-021  UNK      O         m00  Visit-1 only
# 289  RKF-RIL-024   59      F         m00  Visit-1 only
#
#     FDG Visit Date (from DICOM) Unnamed: 17 Completed Protocol? (FDG)  \
# 21          2014-05-20 00:00:00         NaN                         N
# 61          2015-02-23 00:00:00         NaN                         N
# 65          2015-02-24 00:00:00         NaN                         N
# 69          2015-03-10 00:00:00         NaN                         N
# 97                          UNK         NaN                         N
# 107                         UNK         NaN                         N
# 111                         UNK         NaN                         N
# 156         2016-08-23 00:00:00         NaN                         N
# 166         2017-05-17 00:00:00         NaN                         N
# 176         2018-07-20 00:00:00         NaN                         N
# 200         2018-09-11 00:00:00         NaN                         N
# 240         2019-01-29 00:00:00         NaN                         N
# 257         2019-02-25 00:00:00         NaN                         N
# 279         2019-05-15 00:00:00         NaN                         N
# 289         2019-07-24 00:00:00         NaN                         N
#
#                                             LPT Source  FDG_output
# 21   lpt-n2a_sUR_i_n2a_rADNI_APE_792_209A__static-F...        True
# 61   lpt-i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4fra...        True
# 65   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-F...        True
# 69   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-F...        True
# 97   lpt-i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4fra...        True
# 107  lpt-i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4fra...        True
# 111  lpt-i_n2a_sUR_rADNI_mc_APE_792_240a_nifti_4fra...        True
# 156  lpt-i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe...        True
# 166  lpt-i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_...        True
# 176  lpt-i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe...        True
# 200  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multifra...        True
# 240  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multifra...        True
# 257  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multifra...        True
# 279  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multifr...        True
# 289  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multi...        True

# %%
randy_db[['MRI ReName',        '7-Character machine UID', 
]].notna().value_counts()
# Out:
# MRI ReName  7-Character machine UID
# False       False                      217
# True        True                       110
# False       True                         4
# True        False                        4
# dtype: int64

# %%
randy_db[['any_mri_output', 
    'PredictedClass:', 
       ]].value_counts().sort_index()
# Out:
# any_mri_output  PredictedClass:
# True            AD                 55
#                 LBD                 1
#                 MA                 10
#                 NL                  7
#                 SAD                25
#                 SD                  1
# dtype: int64

# %%
randy_db.loc[randy_db['MRI ReName'].notna() & randy_db['any_mri_output']== False,
             [

       
       'MRI ReName',  'any_mri_output' 

       ]
             ].value_counts()
# Out:
# MRI ReName  any_mri_output
# 1.5456      False             1
# 1545.6000   False             1
# dtype: int64

# %%
randy_db.loc[randy_db['MRI ReName'].notna() & randy_db['any_mri_output']== False,
             [
   
       'Subject', 'AGE', 'Gender', 'Visit (ADM)',       
          
       # 'FDG Visit', 'FDG Visit Date (from DICOM)', 'Unnamed: 17',    
        #'FDG multiframe?',  'Image source',  'ProcDate',  
       #'Completed Protocol? (FDG)',
       # 'LPT Source', 'FDG_output',  
       
       'MRI ReName',   
       #'Comment(s)', 'MRI Visit Date',
       'Unnamed: 218', 
       #'Completed Protocol? (MRI)',  
       #'7-Character machine UID', 
       #'Comment(s) -- MRIs as received',   'Image data format',
        #'YYYYMMDD', 'FileName:', 
'any_mri_output', 
    'PredictedClass:', 
       'FS_output', 'FS_pending', 
       'SPM_output', 'SPM_pending'
       ]
             ]
# Out:
#          Subject  AGE Gender Visit (ADM) MRI ReName         Unnamed: 218  \
# 0            NaN  NaN    NaN         NaN        NaN                  NaN
# 4            NaN  NaN    NaN         NaN        NaN                  NaN
# 5            NaN  NaN    NaN         NaN        NaN                  NaN
# 6            NaN  NaN    NaN         NaN        NaN                  NaN
# 8    RKF-APE-005   81      M         m04        NaN  2014-08-11 00:00:00
# ..           ...  ...    ...         ...        ...                  ...
# 330          NaN  NaN    NaN         NaN        NaN                  NaN
# 331          NaN  NaN    NaN         NaN        NaN                  NaN
# 332          NaN  NaN    NaN         NaN        NaN                  NaN
# 333          NaN  NaN    NaN         NaN     1.5456                  NaN
# 334          NaN  NaN    NaN         NaN     1545.6                  NaN
#
#      any_mri_output PredictedClass:  FS_output  FS_pending  SPM_output  \
# 0             False             NaN      False       False       False
# 4             False             NaN      False       False       False
# 5             False             NaN      False       False       False
# 6             False             NaN      False       False       False
# 8             False             NaN      False       False       False
# ..              ...             ...        ...         ...         ...
# 330           False             NaN      False       False       False
# 331           False             NaN      False       False       False
# 332           False             NaN      False       False       False
# 333           False             NaN      False       False       False
# 334           False             NaN      False       False       False
#
#      SPM_pending
# 0          False
# 4          False
# 5          False
# 6          False
# 8          False
# ..           ...
# 330        False
# 331        False
# 332        False
# 333        False
# 334        False
#
# [223 rows x 12 columns]

# %%
randy_db[[ 'any_mri_output']].value_counts()
# Out:
# any_mri_output
# False             222
# True              113
# dtype: int64

# %%
randy_db[[
   
       'Subject', 'AGE', 'Gender', 'Visit (ADM)',       
          
       # 'FDG Visit', 'FDG Visit Date (from DICOM)', 'Unnamed: 17',    
        #'FDG multiframe?',  'Image source',  'ProcDate',  
       #'Completed Protocol? (FDG)',
       # 'LPT Source', 'FDG_output',  
       
       'MRI ReName', 
       #'Comment(s)',   'MRI Visit Date', 'Unnamed: 218', 'Completed Protocol? (MRI)',  
       #'Comment(s) -- MRIs as received',   'Image data format',
       # 'YYYYMMDD', 
       '7-Character machine UID',
       'FileName:', 
'any_mri_output', 
    'PredictedClass:', 
       'FS_output', 'FS_pending', 
       'SPM_output', 'SPM_pending'
       ]]
# Out:
#          Subject  AGE Gender Visit (ADM)  \
# 0            NaN  NaN    NaN         NaN
# 1    RKF-APE-001   76      M         m00
# 2    RKF-APE-001   76      M         m04
# 3    RKF-APE-001   76      M         m06
# 4            NaN  NaN    NaN         NaN
# ..           ...  ...    ...         ...
# 330          NaN  NaN    NaN         NaN
# 331          NaN  NaN    NaN         NaN
# 332          NaN  NaN    NaN         NaN
# 333          NaN  NaN    NaN         NaN
# 334          NaN  NaN    NaN         NaN
#
#                                         MRI ReName 7-Character machine UID  \
# 0                                              NaN                     NaN
# 1    RKF-APE-001__m00__T1-a__20131125__e010542.nii                 e010542
# 2    RKF-APE-001__m04__T1-b__20140403__e010678.nii                 e010678
# 3    RKF-APE-001__m06__T1-c__20140701__n010799.nii                 n010799
# 4                                              NaN                     NaN
# ..                                             ...                     ...
# 330                                            NaN                     NaN
# 331                                            NaN                     NaN
# 332                                            NaN                  0.5035
# 333                                         1.5456                  0.5035
# 334                                         1545.6                   503.5
#
#                                              FileName:  any_mri_output  \
# 0                                                  NaN           False
# 1    n2a_sUR_i_n2a_rADNI_APE_792_201A__static-FDG__...            True
# 2                                                  NaN            True
# 3    n2a_sUR_i_n2a_rADNI_APE_792_201B__static-FDG__...            True
# 4                                                  NaN           False
# ..                                                 ...             ...
# 330                                                NaN           False
# 331                                                NaN           False
# 332                                                NaN           False
# 333                                                NaN           False
# 334                                                NaN           False
#
#     PredictedClass:  FS_output  FS_pending  SPM_output  SPM_pending
# 0               NaN      False       False       False        False
# 1                MA       True       False        True        False
# 2               NaN       True       False        True        False
# 3                MA       True       False        True        False
# 4               NaN      False       False       False        False
# ..              ...        ...         ...         ...          ...
# 330             NaN      False       False       False        False
# 331             NaN      False       False       False        False
# 332             NaN      False       False       False        False
# 333             NaN      False       False       False        False
# 334             NaN      False       False       False        False
#
# [335 rows x 13 columns]

# %%
randy_db.columns
# Out:
# Index(['INDEX-2', 'ProcDate', 'FDG multiframe?', 'INDEX-1', 'FDG Visit',
#        'Completed Protocol? (FDG)', 'Completed Protocol? (MRI)', 'Unnamed: 7',
#        'Subject', 'AGE',
#        ...
#        'AparcPl_meancurv_R_TRANSVTEMP', 'INDEX-1.1', 'INDEX-2.1', 'FDG_output',
#        'FS_output', 'FS_pending', 'SPM_output', 'SPM_pending',
#        'PredictedClass_output', 'any_mri_output'],
#       dtype='object', length=1923)

# %%
randy_db[['INDEX-2', 'ProcDate', 'FDG multiframe?', 'INDEX-1', 'FDG Visit',
       'Completed Protocol? (FDG)', 'Completed Protocol? (MRI)', 'Unnamed: 7',
       'Subject', 'AGE', 'Gender', 'Visit (ALPHA) FDG', 'Visit (ALPHA)  MRI',
       'Visit (ADM)', 'Image source', 'Unnamed: 15',
       'FDG Visit Date (from DICOM)', 'Unnamed: 17', 'FileName:', 'PredictedClass:', 'Grey matter', 'L_Hippocampal_tail']]
# Out:
#      INDEX-2  ProcDate FDG multiframe?  INDEX-1        FDG Visit  \
# 0          1       NaN             NaN      NaN              NaN
# 1          2  20150320             NaN      1.0    Visit-1 (FDG)
# 2          3  20190604             NaN      2.0  Visit-1.5 (MRI)
# 3          4  20150320             NaN      3.0    Visit-2 (FDG)
# 4          5       NaN             NaN      NaN              NaN
# ..       ...       ...             ...      ...              ...
# 330      331       NaN             NaN      NaN              NaN
# 331      332       NaN             NaN      NaN              NaN
# 332      333       NaN             NaN      NaN              NaN
# 333      334       NaN             NaN      NaN              NaN
# 334      335       NaN             NaN      NaN              NaN
#
#     Completed Protocol? (FDG) Completed Protocol? (MRI)  Unnamed: 7  \
# 0                         NaN                       NaN         NaN
# 1                           Y                         Y         NaN
# 2                           X                       MID         NaN
# 3                           Y                         Y         NaN
# 4                         NaN                       NaN         NaN
# ..                        ...                       ...         ...
# 330                       NaN                       NaN         NaN
# 331                       NaN                       NaN         NaN
# 332                       NaN                       NaN         NaN
# 333                       NaN                       NaN         NaN
# 334                       NaN                       NaN         NaN
#
#          Subject  AGE  ... Visit (ALPHA)  MRI Visit (ADM) Image source  \
# 0            NaN  NaN  ...                NaN         NaN          NaN
# 1    RKF-APE-001   76  ...                  A         m00       static
# 2    RKF-APE-001   76  ...                  B         m04          NaN
# 3    RKF-APE-001   76  ...                  C         m06       static
# 4            NaN  NaN  ...                NaN         NaN          NaN
# ..           ...  ...  ...                ...         ...          ...
# 330          NaN  NaN  ...                NaN         NaN          NaN
# 331          NaN  NaN  ...                NaN         NaN          NaN
# 332          NaN  NaN  ...                NaN         NaN          NaN
# 333          NaN  NaN  ...                NaN         NaN          NaN
# 334          NaN  NaN  ...                NaN         NaN          NaN
#
#     Unnamed: 15 FDG Visit Date (from DICOM)          Unnamed: 17  \
# 0           NaN                         NaN                  NaN
# 1           NaN         2013-11-26 00:00:00  2013-11-25 00:00:00
# 2           NaN                         NaN                  NaN
# 3           NaN         2014-06-30 00:00:00  2014-06-30 00:00:00
# 4           NaN                         NaN                  NaN
# ..          ...                         ...                  ...
# 330         NaN                         NaN                  NaN
# 331         NaN                         NaN                  NaN
# 332         NaN                         NaN                  NaN
# 333         NaN                         NaN                  NaN
# 334         NaN                         NaN                  NaN
#
#                                              FileName: PredictedClass:  \
# 0                                                  NaN             NaN
# 1    n2a_sUR_i_n2a_rADNI_APE_792_201A__static-FDG__...              MA
# 2                                                  NaN             NaN
# 3    n2a_sUR_i_n2a_rADNI_APE_792_201B__static-FDG__...              MA
# 4                                                  NaN             NaN
# ..                                                 ...             ...
# 330                                                NaN             NaN
# 331                                                NaN             NaN
# 332                                                NaN             NaN
# 333                                                NaN             NaN
# 334                                                NaN             NaN
#
#     Grey matter L_Hippocampal_tail
# 0           NaN                NaN
# 1      147453.0          394.74403
# 2           NaN         387.888615
# 3      148920.0         337.627806
# 4           NaN                NaN
# ..          ...                ...
# 330         NaN                NaN
# 331         NaN                NaN
# 332         NaN                NaN
# 333         NaN                NaN
# 334         NaN                NaN
#
# [335 rows x 22 columns]

# %%
randy_db_subset = randy_db[[
       'Subject', 'AGE', 'Gender', 'Visit (ADM)',       
        'LPT Source', 'FileName:', 'FDG_output',  
       'MRI ReName',  'FS_output'

]]

randy_db_subset = randy_db_subset[randy_db_subset['Visit (ADM)'].isin(['m00', 'm00x', np.nan])].reset_index(drop = True)
randy_db_subset = randy_db_subset[randy_db_subset['Subject'].notna()].reset_index(drop = True)

#randy_db_subset = randy_db_subset[(randy_db_subset['FDG_output'] == True) | (randy_db_subset['FS_output'] == True) | (randy_db_subset['MRI ReName'].notna())]

# %%
randy_db_subset['Subject_Label'] = randy_db_subset['Subject'].str[4:7].str.replace('APE', 'APE-792')
randy_db_subset['Subject_Num'] = randy_db_subset['Subject'].str[8:].astype('int')
randy_db_subset['ID_ADM'] = randy_db_subset['Subject_Label'] + '_' + randy_db_subset['Subject_Num'].astype('str')

# %%
randy_db_subset
# Out:
#         Subject                 AGE Gender Visit (ADM)  \
# 0   RKF-APE-001                  76      M         m00
# 1   RKF-APE-005                  81      M         m00
# 2   RKF-APE-007                  67      F         m00
# 3   RKF-APE-009                  75      M         m00
# 4   RKF-APE-010                  58      F         m00
# 5   RKF-APE-011                  81      F         m00
# 6   RKF-APE-013                  80      F         m00
# 7   RKF-APE-016                  77      F         m00
# 8   RKF-APE-018                  73      F         m00
# 9   RKF-APE-020                  71      F         m00
# 10  RKF-APE-021                 UNK      O         m00
# 11  RKF-APE-022                 UNK      O         m00
# 12  RKF-APE-023                 UNK      O         m00
# 13  RKF-APE-026  72 (DICOM says 74)      F         m00
# 14  RKF-APE-027                  84      F         m00
# 15  RKF-APE-033                  68      F         m00
# 16  RKF-APE-034  82 (DICOM says 84)      F         m00
# 17  RKF-APE-035                 UNK      O         m00
# 18  RKF-APE-036                  79      F         m00
# 19  RKF-APE-039                 UNK      O         m00
# 20  RKF-APE-040                 UNK      O         m00
# 21  RKF-APE-046                  72      F         m00
# 22  RKF-APE-047                  77      M         m00
# 23  RKF-APE-050                  60      M         m00
# 24  RKF-APE-053                  77      F         m00
# 25  RKF-APE-055                  81      M         NaN
# 26  RKF-APE-056  79 (DICOM says 81)      F         m00
# 27  RKF-APE-058                  78      M         m00
# 28  RKF-APE-060                 UNK      O         m00
# 29  RKF-APE-062  74 (DICOM says 75)      M         m00
# 30  RKF-APE-065                  81      M         m00
# 31  RKF-APE-066  75 (DICOM says 76)      M         m00
# 32  RKF-APE-071                  69      M         m00
# 33  RKF-RIL-001                  60      F         m00
# 34  RKF-RIL-002                  76      F         m00
# 35  RKF-RIL-003                  77      M         NaN
# 36  RKF-RIL-005                 UNK      O         NaN
# 37  RKF-RIL-007                  80      M        m00x
# 38  RKF-RIL-008                  71      M         m00
# 39  RKF-RIL-009                  74      M        m00x
# 40  RKF-RIL-010                  66      F         m00
# 41  RKF-RIL-011                  86      F         m00
# 42  RKF-RIL-012                  82      F         m00
# 43  RKF-RIL-013                  70      M         m00
# 44  RKF-RIL-014                  77      M         m00
# 45  RKF-RIL-015                  79      M         m00
# 46  RKF-RIL-017                  76      F         m00
# 47  RKF-RIL-018                  67      M         m00
# 48  RKF-RIL-019                  88      F         m00
# 49  RKF-RIL-020                  81      F         m00
# 50  RKF-RIL-021                 UNK      O         m00
# 51  RKF-RIL-022                  76      F         m00
# 52  RKF-RIL-024                  59      F         m00
# 53  RKF-RIL-025                  69      F         m00
# 54  RKF-RIL-027                  75      F         m00
# 55  RKF-RIL-028  77 (DICOM says 78)      M         m00
# 56  RKF-RIL-029                  74      F         m00
# 57  RKF-RIL-031  72 (DICOM says 73)      M         m00
#
#                                            LPT Source  \
# 0   lpt-n2a_sUR_i_n2a_rADNI_APE_792_201A__static-F...
# 1   lpt-n2a_sUR_i_n2a_rADNI_APE_792_205A__static-F...
# 2   lpt-sUR_i_n2a_rADNI_APE_792_207A_frame1__nmsks...
# 3   lpt-n2a_sUR_i_n2a_rADNI_APE_792_209A__static-F...
# 4   lpt-n2a_sUR_i_n2a_rADNI_APE_792_210A__static-F...
# 5   lpt-n2a_sUR_i_n2a_rADNI_APE_792_211A__static-F...
# 6   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_213A__dyn-F...
# 7   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_216A__dyn-F...
# 8   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_218A__dyn-F...
# 9   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_220A__dyn-F...
# 10  lpt-i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4fra...
# 11  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-F...
# 12  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-F...
# 13  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_226A__dyn-F...
# 14  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_227A__dyn-F...
# 15  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_233A__dyn-F...
# 16  lpt-i_n2a_sUR_rADNI_mc_APE_792_234a_nifti_4fra...
# 17  lpt-i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4fra...
# 18  lpt-i_n2a_sUR_rADNI_mc_APE_792_236A_nifti_4fra...
# 19  lpt-i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4fra...
# 20  lpt-i_n2a_sUR_rADNI_mc_APE_792_240a_nifti_4fra...
# 21  lpt-i_n2a_sUR_rADNI_mc_APE_792_246A_nifti_4fra...
# 22  lpt-i_n2a_sUR_rADNI_mc_APE_792_247a_nifti_4fra...
# 23  lpt-i_n2a_sUR_rADNI_mc_APE-792-250a_frame1alig...
# 24  lpt-i_n2a_sUR_rADNI_mc_APE_792_253a_nifti_4fra...
# 25                                                NaN
# 26  lpt-i_n2a_sUR_rADNI_mc_APE_792_256A_multiframe...
# 27  lpt-i_n2a_sUR_rADNI_mc_APE_792_258A_multiframe...
# 28  lpt-i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe...
# 29  lpt-i_n2a_sUR_rADNI_mc_APE_792_262A_multiframe...
# 30  lpt-i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_...
# 31  lpt-i_n2a_sUR_rADNI_mc_APE_792_266A_mutiframe_...
# 32  lpt-i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe...
# 33  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2001A_multifram...
# 34  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2002A_multifram...
# 35  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2003A_multifram...
# 36  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multifra...
# 37  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2007A_multifra...
# 38  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2008A_mutifram...
# 39  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_1009A_mutiframe...
# 40  lpt-i_n2a_sUR_rADNI_mc_uo_RIL-1010A_multiframe...
# 41  lpt-i_n2a_sUR_rADNI_mc_uo_RIL-1011A_multiframe...
# 42  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2012A_multifram...
# 43  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multifra...
# 44  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2014A_multifram...
# 45  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2015A_multifram...
# 46  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multifra...
# 47  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2018A_multifra...
# 48  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2019A_multifram...
# 49  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2020A_multifram...
# 50  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multifr...
# 51  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2022A_multifram...
# 52  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multi...
# 53  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2025A_multifram...
# 54  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2027A_multifram...
# 55  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL-2028A_multifr...
# 56  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2029A_multi...
# 57  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL-031A_multifra...
#
#                                             FileName:  FDG_output  \
# 0   n2a_sUR_i_n2a_rADNI_APE_792_201A__static-FDG__...        True
# 1   n2a_sUR_i_n2a_rADNI_APE_792_205A__static-FDG__...        True
# 2   sUR_i_n2a_rADNI_APE_792_207A_frame1__nmsks.sn.img        True
# 3   n2a_sUR_i_n2a_rADNI_APE_792_209A__static-FDG__...        True
# 4   n2a_sUR_i_n2a_rADNI_APE_792_210A__static-FDG__...        True
# 5   n2a_sUR_i_n2a_rADNI_APE_792_211A__static-FDG__...        True
# 6   n2a_sUR_i_n2a_rADNI_mc_APE_792_213A__dyn-FDG_0...        True
# 7   n2a_sUR_i_n2a_rADNI_mc_APE_792_216A__dyn-FDG_0...        True
# 8   n2a_sUR_i_n2a_rADNI_mc_APE_792_218A__dyn-FDG_0...        True
# 9   n2a_sUR_i_n2a_rADNI_mc_APE_792_220A__dyn-FDG_0...        True
# 10  i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4frame_0...        True
# 11  n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-FDG_0...        True
# 12  n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-FDG_0...        True
# 13  sUR_i_n2a_rADNI_mc_APE-792-226A__dyn-FDG_00001...        True
# 14  sUR_i_n2a_rADNI_mc_APE-792-227A__dyn-FDG_00001...        True
# 15  n2a_sUR_i_n2a_rADNI_mc_APE_792_233A__dyn-FDG_0...        True
# 16  i_n2a_sUR_rADNI_mc_APE_792_234a_nifti_4frame_0...        True
# 17  i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4frame_0...        True
# 18  i_n2a_sUR_rADNI_mc_APE_792_236A_nifti_4frame_0...        True
# 19  i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4frame_0...        True
# 20  i_n2a_sUR_rADNI_mc_APE_792_240a_multiframe_000...        True
# 21  i_n2a_sUR_rADNI_mc_APE_792_246A_nifti_4frame_0...        True
# 22  i_n2a_sUR_rADNI_mc_APE_792_247a_nifti_4frame_0...        True
# 23  i_n2a_sUR_rADNI_mc_APE-792-250a_frame1alignedt...        True
# 24  i_n2a_sUR_rADNI_mc_APE_792_253a_nifti_4frame_0...        True
# 25                                                NaN       False
# 26  i_n2a_sUR_rADNI_mc_APE_792_256A_multiframe_000...        True
# 27  i_n2a_sUR_rADNI_mc_APE_792_258A_multiframe_000...        True
# 28  i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe_000...        True
# 29  i_n2a_sUR_rADNI_mc_APE_792_262A_multiframe_000...        True
# 30  i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_0000...        True
# 31  i_n2a_sUR_rADNI_mc_APE_792_266A_mutiframe_0000...        True
# 32  i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe_000...        True
# 33  i_n2a_sUR_rADNI_mc_o_RIL_S_2001A_multiframe_00...        True
# 34  i_n2a_sUR_rADNI_mc_o_RIL_S_2002A_multiframe_00...        True
# 35  i_n2a_sUR_rADNI_mc_o_RIL_S_2003A_multiframe_00...        True
# 36  i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multiframe_0...        True
# 37  i_n2a_sUR_rADNI_mc_uo_RIL_S_2007A_multiframe_0...        True
# 38  i_n2a_sUR_rADNI_mc_uo_RIL_S_2008A_mutiframe_00...        True
# 39  i_n2a_sUR_rADNI_mc_o_RIL_S_1009A_mutiframe_000...        True
# 40  i_n2a_sUR_rADNI_mc_uo_RIL-1010A_multiframe_000...        True
# 41  i_n2a_sUR_rADNI_mc_uo_RIL-1011A_multiframe_000...        True
# 42  i_n2a_sUR_rADNI_mc_o_RIL_S_2012A_multiframe_00...        True
# 43  i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multiframe_0...        True
# 44  i_n2a_sUR_rADNI_mc_o_RIL_S_2014A_multiframe_00...        True
# 45  i_n2a_sUR_rADNI_mc_o_RIL_S_2015A_multiframe_00...        True
# 46  i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multiframe_0...        True
# 47  i_n2a_sUR_rADNI_mc_uo_RIL_S_2018A_multiframe_0...        True
# 48  i_n2a_sUR_rADNI_mc_o_RIL_S_2019A_multiframe_00...        True
# 49  i_n2a_sUR_rADNI_mc_o_RIL_S_2020A_multiframe_00...        True
# 50  i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multiframe_...        True
# 51  i_n2a_sUR_rADNI_mc_o_RIL_S_2022A_multiframe_00...        True
# 52  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multifram...        True
# 53  i_n2a_sUR_rADNI_meano_RIL_S_2025A_multiframe_0...        True
# 54  i_n2a_sUR_rADNI_mc_o_RIL_S_2027A_multiframe_00...        True
# 55  i_n2a_sUR_rADNI_mc_o_RKF-RIL-2028A_multiframe_...        True
# 56  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2029A_multifram...        True
# 57  i_n2a_sUR_rADNI_mc_o_RKF-RIL-031A_multiframe_0...        True
#
#                                         MRI ReName  FS_output Subject_Label  \
# 0    RKF-APE-001__m00__T1-a__20131125__e010542.nii       True       APE-792
# 1    RKF-APE-005__m00__T1-a__20140428__e010707.nii       True       APE-792
# 2    RKF-APE-007__m00__T1-a__20140418__e010695.nii       True       APE-792
# 3    RKF-APE-009__m00__T1-a__20140520__e010737.nii       True       APE-792
# 4    RKF-APE-010__m00__T1-a__20140530__e010753.nii       True       APE-792
# 5    RKF-APE-011__m00__T1-a__20140527__e010746.nii       True       APE-792
# 6    RKF-APE-013__m00__T1-a__20140630__e010796.nii       True       APE-792
# 7    RKF-APE-016__m00__T1-a__20141121__n115548.nii       True       APE-792
# 8    RKF-APE-018__m00__T1-a__20141125__n102556.nii       True       APE-792
# 9    RKF-APE-020__m00__T1-a__20141126__n112426.nii       True       APE-792
# 10                                        PENDING?      False       APE-792
# 11   RKF-APE-022__m00__T1-a__20150224__n123534.nii       True       APE-792
# 12   RKF-APE-023__m00__T1-a__20150310__n114941.nii       True       APE-792
# 13                                         PENDING      False       APE-792
# 14   RKF-APE-027__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 15   RKF-APE-033__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 16   RKF-APE-034__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 17   RKF-APE-035__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 18   RKF-APE-036__m00__T1-a__2016xxxx__saNiFTI.nii       True       APE-792
# 19   RKF-APE-039__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 20                                        PENDING?      False       APE-792
# 21   RKF-APE-046__m00__T1-a__20150928__e011544.nii       True       APE-792
# 22   RKF-APE-047__m00__T1-a__20150824__e011493.nii      False       APE-792
# 23   RKF-APE-050__m00__T1-a__20151008__e011560.nii       True       APE-792
# 24   RKF-APE-053__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 25                                             NaN      False       APE-792
# 26                                        PENDING?      False       APE-792
# 27   RKF-APE-058__m00__T1-a__20161011__e011842.nii       True       APE-792
# 28                                        PENDING?      False       APE-792
# 29   RKF-APE-062__m00__T1-a__20170214__e012034.nii       True       APE-792
# 30   RKF-APE-065__m00__T1-a__20170517__e012169.nii       True       APE-792
# 31                                        PENDING?      False       APE-792
# 32   RKF-APE-071__m00__T1-a__20180720__e012994.nii       True       APE-792
# 33   RKF-RIL-001__m00__T1-a__20180518__e012890.nii      False           RIL
# 34   RKF-RIL-002__m00__T1-a__20180615__e012940.nii      False           RIL
# 35   RKF-RIL-003__m06__T1-c__20190304__e013465.nii      False           RIL
# 36                                        PENDING?      False           RIL
# 37  RKF-RIL-007__m00x__T1-b__20181211__e013282.nii       True           RIL
# 38   RKF-RIL-008__m00__T1-a__20181005__e013155.nii       True           RIL
# 39   RKF-RIL-009__m00__T1-a__20181016__e013178.nii      False           RIL
# 40   RKF-RIL-010__m00__T1-a__20181109__e013221.nii       True           RIL
# 41   RKF-RIL-011__m00__T1-a__20181108__e013219.nii       True           RIL
# 42   RKF-RIL-012__m00__T1-a__20181218__e013304.nii       True           RIL
# 43   RKF-RIL-013__m00__T1-a__20190129__e013380.nii       True           RIL
# 44   RKF-RIL-014__m00__T1-a__20181221__e013312.nii       True           RIL
# 45   RKF-RIL-015__m00__T1-a__20190326__e013512.nii       True           RIL
# 46   RKF-RIL-017__m00__T1-a__20190225__e013451.nii       True           RIL
# 47   RKF-RIL-018__m00__T1-a__20190227__e013459.nii       True           RIL
# 48   RKF-RIL-019__m00__T1-a__20190409__e013550.nii       True           RIL
# 49   RKF-RIL-020__m00__T1-a__20190410__e013552.nii       True           RIL
# 50   RKF-RIL-021__m00__T1-a__20190515__e013645.nii       True           RIL
# 51   RKF-RIL-022__m00__T1-a__20190528__e013678.nii       True           RIL
# 52   RKF-RIL-024__m00__T1-a__20190724__e013826.nii       True           RIL
# 53   RKF-RIL-025__m00__T1-a__20190607__e013707.nii       True           RIL
# 54   RKF-RIL-027__m00__T1-a__20190614__e014208.nii      False           RIL
# 55   RKF-RIL-028__m00__T1-a__20190726__e013839.nii       True           RIL
# 56   RKF-RIL-029__m00__T1-a__20190806__e013866.nii       True           RIL
# 57   RKF-RIL-031__m00__T1-a__20191016__e014066.nii      False           RIL
#
#     Subject_Num      ID_ADM
# 0             1   APE-792_1
# 1             5   APE-792_5
# 2             7   APE-792_7
# 3             9   APE-792_9
# 4            10  APE-792_10
# 5            11  APE-792_11
# 6            13  APE-792_13
# 7            16  APE-792_16
# 8            18  APE-792_18
# 9            20  APE-792_20
# 10           21  APE-792_21
# 11           22  APE-792_22
# 12           23  APE-792_23
# 13           26  APE-792_26
# 14           27  APE-792_27
# 15           33  APE-792_33
# 16           34  APE-792_34
# 17           35  APE-792_35
# 18           36  APE-792_36
# 19           39  APE-792_39
# 20           40  APE-792_40
# 21           46  APE-792_46
# 22           47  APE-792_47
# 23           50  APE-792_50
# 24           53  APE-792_53
# 25           55  APE-792_55
# 26           56  APE-792_56
# 27           58  APE-792_58
# 28           60  APE-792_60
# 29           62  APE-792_62
# 30           65  APE-792_65
# 31           66  APE-792_66
# 32           71  APE-792_71
# 33            1       RIL_1
# 34            2       RIL_2
# 35            3       RIL_3
# 36            5       RIL_5
# 37            7       RIL_7
# 38            8       RIL_8
# 39            9       RIL_9
# 40           10      RIL_10
# 41           11      RIL_11
# 42           12      RIL_12
# 43           13      RIL_13
# 44           14      RIL_14
# 45           15      RIL_15
# 46           17      RIL_17
# 47           18      RIL_18
# 48           19      RIL_19
# 49           20      RIL_20
# 50           21      RIL_21
# 51           22      RIL_22
# 52           24      RIL_24
# 53           25      RIL_25
# 54           27      RIL_27
# 55           28      RIL_28
# 56           29      RIL_29
# 57           31      RIL_31

# %%
randy_db_subset['Subject'].value_counts()
# Out:
# RKF-APE-001    1
# RKF-RIL-013    1
# RKF-APE-066    1
# RKF-APE-071    1
# RKF-RIL-001    1
# RKF-RIL-002    1
# RKF-RIL-003    1
# RKF-RIL-005    1
# RKF-RIL-007    1
# RKF-RIL-008    1
# RKF-RIL-009    1
# RKF-RIL-010    1
# RKF-RIL-011    1
# RKF-RIL-012    1
# RKF-RIL-014    1
# RKF-APE-005    1
# RKF-RIL-015    1
# RKF-RIL-017    1
# RKF-RIL-018    1
# RKF-RIL-019    1
# RKF-RIL-020    1
# RKF-RIL-021    1
# RKF-RIL-022    1
# RKF-RIL-024    1
# RKF-RIL-025    1
# RKF-RIL-027    1
# RKF-RIL-028    1
# RKF-RIL-029    1
# RKF-APE-065    1
# RKF-APE-062    1
# RKF-APE-060    1
# RKF-APE-058    1
# RKF-APE-007    1
# RKF-APE-009    1
# RKF-APE-010    1
# RKF-APE-011    1
# RKF-APE-013    1
# RKF-APE-016    1
# RKF-APE-018    1
# RKF-APE-020    1
# RKF-APE-021    1
# RKF-APE-022    1
# RKF-APE-023    1
# RKF-APE-026    1
# RKF-APE-027    1
# RKF-APE-033    1
# RKF-APE-034    1
# RKF-APE-035    1
# RKF-APE-036    1
# RKF-APE-039    1
# RKF-APE-040    1
# RKF-APE-046    1
# RKF-APE-047    1
# RKF-APE-050    1
# RKF-APE-053    1
# RKF-APE-055    1
# RKF-APE-056    1
# RKF-RIL-031    1
# Name: Subject, dtype: int64

# %% [markdown]
# ## compare to plasma

# %%
randy_db_subset
# Out:
#         Subject                 AGE Gender Visit (ADM)  \
# 0   RKF-APE-001                  76      M         m00
# 1   RKF-APE-005                  81      M         m00
# 2   RKF-APE-007                  67      F         m00
# 3   RKF-APE-009                  75      M         m00
# 4   RKF-APE-010                  58      F         m00
# 5   RKF-APE-011                  81      F         m00
# 6   RKF-APE-013                  80      F         m00
# 7   RKF-APE-016                  77      F         m00
# 8   RKF-APE-018                  73      F         m00
# 9   RKF-APE-020                  71      F         m00
# 10  RKF-APE-021                 UNK      O         m00
# 11  RKF-APE-022                 UNK      O         m00
# 12  RKF-APE-023                 UNK      O         m00
# 13  RKF-APE-026  72 (DICOM says 74)      F         m00
# 14  RKF-APE-027                  84      F         m00
# 15  RKF-APE-033                  68      F         m00
# 16  RKF-APE-034  82 (DICOM says 84)      F         m00
# 17  RKF-APE-035                 UNK      O         m00
# 18  RKF-APE-036                  79      F         m00
# 19  RKF-APE-039                 UNK      O         m00
# 20  RKF-APE-040                 UNK      O         m00
# 21  RKF-APE-046                  72      F         m00
# 22  RKF-APE-047                  77      M         m00
# 23  RKF-APE-050                  60      M         m00
# 24  RKF-APE-053                  77      F         m00
# 25  RKF-APE-055                  81      M         NaN
# 26  RKF-APE-056  79 (DICOM says 81)      F         m00
# 27  RKF-APE-058                  78      M         m00
# 28  RKF-APE-060                 UNK      O         m00
# 29  RKF-APE-062  74 (DICOM says 75)      M         m00
# 30  RKF-APE-065                  81      M         m00
# 31  RKF-APE-066  75 (DICOM says 76)      M         m00
# 32  RKF-APE-071                  69      M         m00
# 33  RKF-RIL-001                  60      F         m00
# 34  RKF-RIL-002                  76      F         m00
# 35  RKF-RIL-003                  77      M         NaN
# 36  RKF-RIL-005                 UNK      O         NaN
# 37  RKF-RIL-007                  80      M        m00x
# 38  RKF-RIL-008                  71      M         m00
# 39  RKF-RIL-009                  74      M        m00x
# 40  RKF-RIL-010                  66      F         m00
# 41  RKF-RIL-011                  86      F         m00
# 42  RKF-RIL-012                  82      F         m00
# 43  RKF-RIL-013                  70      M         m00
# 44  RKF-RIL-014                  77      M         m00
# 45  RKF-RIL-015                  79      M         m00
# 46  RKF-RIL-017                  76      F         m00
# 47  RKF-RIL-018                  67      M         m00
# 48  RKF-RIL-019                  88      F         m00
# 49  RKF-RIL-020                  81      F         m00
# 50  RKF-RIL-021                 UNK      O         m00
# 51  RKF-RIL-022                  76      F         m00
# 52  RKF-RIL-024                  59      F         m00
# 53  RKF-RIL-025                  69      F         m00
# 54  RKF-RIL-027                  75      F         m00
# 55  RKF-RIL-028  77 (DICOM says 78)      M         m00
# 56  RKF-RIL-029                  74      F         m00
# 57  RKF-RIL-031  72 (DICOM says 73)      M         m00
#
#                                            LPT Source  \
# 0   lpt-n2a_sUR_i_n2a_rADNI_APE_792_201A__static-F...
# 1   lpt-n2a_sUR_i_n2a_rADNI_APE_792_205A__static-F...
# 2   lpt-sUR_i_n2a_rADNI_APE_792_207A_frame1__nmsks...
# 3   lpt-n2a_sUR_i_n2a_rADNI_APE_792_209A__static-F...
# 4   lpt-n2a_sUR_i_n2a_rADNI_APE_792_210A__static-F...
# 5   lpt-n2a_sUR_i_n2a_rADNI_APE_792_211A__static-F...
# 6   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_213A__dyn-F...
# 7   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_216A__dyn-F...
# 8   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_218A__dyn-F...
# 9   lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_220A__dyn-F...
# 10  lpt-i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4fra...
# 11  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-F...
# 12  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-F...
# 13  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_226A__dyn-F...
# 14  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_227A__dyn-F...
# 15  lpt-n2a_sUR_i_n2a_rADNI_mc_APE_792_233A__dyn-F...
# 16  lpt-i_n2a_sUR_rADNI_mc_APE_792_234a_nifti_4fra...
# 17  lpt-i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4fra...
# 18  lpt-i_n2a_sUR_rADNI_mc_APE_792_236A_nifti_4fra...
# 19  lpt-i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4fra...
# 20  lpt-i_n2a_sUR_rADNI_mc_APE_792_240a_nifti_4fra...
# 21  lpt-i_n2a_sUR_rADNI_mc_APE_792_246A_nifti_4fra...
# 22  lpt-i_n2a_sUR_rADNI_mc_APE_792_247a_nifti_4fra...
# 23  lpt-i_n2a_sUR_rADNI_mc_APE-792-250a_frame1alig...
# 24  lpt-i_n2a_sUR_rADNI_mc_APE_792_253a_nifti_4fra...
# 25                                                NaN
# 26  lpt-i_n2a_sUR_rADNI_mc_APE_792_256A_multiframe...
# 27  lpt-i_n2a_sUR_rADNI_mc_APE_792_258A_multiframe...
# 28  lpt-i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe...
# 29  lpt-i_n2a_sUR_rADNI_mc_APE_792_262A_multiframe...
# 30  lpt-i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_...
# 31  lpt-i_n2a_sUR_rADNI_mc_APE_792_266A_mutiframe_...
# 32  lpt-i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe...
# 33  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2001A_multifram...
# 34  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2002A_multifram...
# 35  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2003A_multifram...
# 36  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multifra...
# 37  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2007A_multifra...
# 38  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2008A_mutifram...
# 39  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_1009A_mutiframe...
# 40  lpt-i_n2a_sUR_rADNI_mc_uo_RIL-1010A_multiframe...
# 41  lpt-i_n2a_sUR_rADNI_mc_uo_RIL-1011A_multiframe...
# 42  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2012A_multifram...
# 43  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multifra...
# 44  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2014A_multifram...
# 45  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2015A_multifram...
# 46  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multifra...
# 47  lpt-i_n2a_sUR_rADNI_mc_uo_RIL_S_2018A_multifra...
# 48  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2019A_multifram...
# 49  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2020A_multifram...
# 50  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multifr...
# 51  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2022A_multifram...
# 52  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multi...
# 53  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2025A_multifram...
# 54  lpt-i_n2a_sUR_rADNI_mc_o_RIL_S_2027A_multifram...
# 55  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL-2028A_multifr...
# 56  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2029A_multi...
# 57  lpt-i_n2a_sUR_rADNI_mc_o_RKF-RIL-031A_multifra...
#
#                                             FileName:  FDG_output  \
# 0   n2a_sUR_i_n2a_rADNI_APE_792_201A__static-FDG__...        True
# 1   n2a_sUR_i_n2a_rADNI_APE_792_205A__static-FDG__...        True
# 2   sUR_i_n2a_rADNI_APE_792_207A_frame1__nmsks.sn.img        True
# 3   n2a_sUR_i_n2a_rADNI_APE_792_209A__static-FDG__...        True
# 4   n2a_sUR_i_n2a_rADNI_APE_792_210A__static-FDG__...        True
# 5   n2a_sUR_i_n2a_rADNI_APE_792_211A__static-FDG__...        True
# 6   n2a_sUR_i_n2a_rADNI_mc_APE_792_213A__dyn-FDG_0...        True
# 7   n2a_sUR_i_n2a_rADNI_mc_APE_792_216A__dyn-FDG_0...        True
# 8   n2a_sUR_i_n2a_rADNI_mc_APE_792_218A__dyn-FDG_0...        True
# 9   n2a_sUR_i_n2a_rADNI_mc_APE_792_220A__dyn-FDG_0...        True
# 10  i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4frame_0...        True
# 11  n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-FDG_0...        True
# 12  n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-FDG_0...        True
# 13  sUR_i_n2a_rADNI_mc_APE-792-226A__dyn-FDG_00001...        True
# 14  sUR_i_n2a_rADNI_mc_APE-792-227A__dyn-FDG_00001...        True
# 15  n2a_sUR_i_n2a_rADNI_mc_APE_792_233A__dyn-FDG_0...        True
# 16  i_n2a_sUR_rADNI_mc_APE_792_234a_nifti_4frame_0...        True
# 17  i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4frame_0...        True
# 18  i_n2a_sUR_rADNI_mc_APE_792_236A_nifti_4frame_0...        True
# 19  i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4frame_0...        True
# 20  i_n2a_sUR_rADNI_mc_APE_792_240a_multiframe_000...        True
# 21  i_n2a_sUR_rADNI_mc_APE_792_246A_nifti_4frame_0...        True
# 22  i_n2a_sUR_rADNI_mc_APE_792_247a_nifti_4frame_0...        True
# 23  i_n2a_sUR_rADNI_mc_APE-792-250a_frame1alignedt...        True
# 24  i_n2a_sUR_rADNI_mc_APE_792_253a_nifti_4frame_0...        True
# 25                                                NaN       False
# 26  i_n2a_sUR_rADNI_mc_APE_792_256A_multiframe_000...        True
# 27  i_n2a_sUR_rADNI_mc_APE_792_258A_multiframe_000...        True
# 28  i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe_000...        True
# 29  i_n2a_sUR_rADNI_mc_APE_792_262A_multiframe_000...        True
# 30  i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_0000...        True
# 31  i_n2a_sUR_rADNI_mc_APE_792_266A_mutiframe_0000...        True
# 32  i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe_000...        True
# 33  i_n2a_sUR_rADNI_mc_o_RIL_S_2001A_multiframe_00...        True
# 34  i_n2a_sUR_rADNI_mc_o_RIL_S_2002A_multiframe_00...        True
# 35  i_n2a_sUR_rADNI_mc_o_RIL_S_2003A_multiframe_00...        True
# 36  i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multiframe_0...        True
# 37  i_n2a_sUR_rADNI_mc_uo_RIL_S_2007A_multiframe_0...        True
# 38  i_n2a_sUR_rADNI_mc_uo_RIL_S_2008A_mutiframe_00...        True
# 39  i_n2a_sUR_rADNI_mc_o_RIL_S_1009A_mutiframe_000...        True
# 40  i_n2a_sUR_rADNI_mc_uo_RIL-1010A_multiframe_000...        True
# 41  i_n2a_sUR_rADNI_mc_uo_RIL-1011A_multiframe_000...        True
# 42  i_n2a_sUR_rADNI_mc_o_RIL_S_2012A_multiframe_00...        True
# 43  i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multiframe_0...        True
# 44  i_n2a_sUR_rADNI_mc_o_RIL_S_2014A_multiframe_00...        True
# 45  i_n2a_sUR_rADNI_mc_o_RIL_S_2015A_multiframe_00...        True
# 46  i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multiframe_0...        True
# 47  i_n2a_sUR_rADNI_mc_uo_RIL_S_2018A_multiframe_0...        True
# 48  i_n2a_sUR_rADNI_mc_o_RIL_S_2019A_multiframe_00...        True
# 49  i_n2a_sUR_rADNI_mc_o_RIL_S_2020A_multiframe_00...        True
# 50  i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multiframe_...        True
# 51  i_n2a_sUR_rADNI_mc_o_RIL_S_2022A_multiframe_00...        True
# 52  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multifram...        True
# 53  i_n2a_sUR_rADNI_meano_RIL_S_2025A_multiframe_0...        True
# 54  i_n2a_sUR_rADNI_mc_o_RIL_S_2027A_multiframe_00...        True
# 55  i_n2a_sUR_rADNI_mc_o_RKF-RIL-2028A_multiframe_...        True
# 56  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2029A_multifram...        True
# 57  i_n2a_sUR_rADNI_mc_o_RKF-RIL-031A_multiframe_0...        True
#
#                                         MRI ReName  FS_output Subject_Label  \
# 0    RKF-APE-001__m00__T1-a__20131125__e010542.nii       True       APE-792
# 1    RKF-APE-005__m00__T1-a__20140428__e010707.nii       True       APE-792
# 2    RKF-APE-007__m00__T1-a__20140418__e010695.nii       True       APE-792
# 3    RKF-APE-009__m00__T1-a__20140520__e010737.nii       True       APE-792
# 4    RKF-APE-010__m00__T1-a__20140530__e010753.nii       True       APE-792
# 5    RKF-APE-011__m00__T1-a__20140527__e010746.nii       True       APE-792
# 6    RKF-APE-013__m00__T1-a__20140630__e010796.nii       True       APE-792
# 7    RKF-APE-016__m00__T1-a__20141121__n115548.nii       True       APE-792
# 8    RKF-APE-018__m00__T1-a__20141125__n102556.nii       True       APE-792
# 9    RKF-APE-020__m00__T1-a__20141126__n112426.nii       True       APE-792
# 10                                        PENDING?      False       APE-792
# 11   RKF-APE-022__m00__T1-a__20150224__n123534.nii       True       APE-792
# 12   RKF-APE-023__m00__T1-a__20150310__n114941.nii       True       APE-792
# 13                                         PENDING      False       APE-792
# 14   RKF-APE-027__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 15   RKF-APE-033__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 16   RKF-APE-034__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 17   RKF-APE-035__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 18   RKF-APE-036__m00__T1-a__2016xxxx__saNiFTI.nii       True       APE-792
# 19   RKF-APE-039__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 20                                        PENDING?      False       APE-792
# 21   RKF-APE-046__m00__T1-a__20150928__e011544.nii       True       APE-792
# 22   RKF-APE-047__m00__T1-a__20150824__e011493.nii      False       APE-792
# 23   RKF-APE-050__m00__T1-a__20151008__e011560.nii       True       APE-792
# 24   RKF-APE-053__m00__T1-a__2015xxxx__saNiFTI.nii       True       APE-792
# 25                                             NaN      False       APE-792
# 26                                        PENDING?      False       APE-792
# 27   RKF-APE-058__m00__T1-a__20161011__e011842.nii       True       APE-792
# 28                                        PENDING?      False       APE-792
# 29   RKF-APE-062__m00__T1-a__20170214__e012034.nii       True       APE-792
# 30   RKF-APE-065__m00__T1-a__20170517__e012169.nii       True       APE-792
# 31                                        PENDING?      False       APE-792
# 32   RKF-APE-071__m00__T1-a__20180720__e012994.nii       True       APE-792
# 33   RKF-RIL-001__m00__T1-a__20180518__e012890.nii      False           RIL
# 34   RKF-RIL-002__m00__T1-a__20180615__e012940.nii      False           RIL
# 35   RKF-RIL-003__m06__T1-c__20190304__e013465.nii      False           RIL
# 36                                        PENDING?      False           RIL
# 37  RKF-RIL-007__m00x__T1-b__20181211__e013282.nii       True           RIL
# 38   RKF-RIL-008__m00__T1-a__20181005__e013155.nii       True           RIL
# 39   RKF-RIL-009__m00__T1-a__20181016__e013178.nii      False           RIL
# 40   RKF-RIL-010__m00__T1-a__20181109__e013221.nii       True           RIL
# 41   RKF-RIL-011__m00__T1-a__20181108__e013219.nii       True           RIL
# 42   RKF-RIL-012__m00__T1-a__20181218__e013304.nii       True           RIL
# 43   RKF-RIL-013__m00__T1-a__20190129__e013380.nii       True           RIL
# 44   RKF-RIL-014__m00__T1-a__20181221__e013312.nii       True           RIL
# 45   RKF-RIL-015__m00__T1-a__20190326__e013512.nii       True           RIL
# 46   RKF-RIL-017__m00__T1-a__20190225__e013451.nii       True           RIL
# 47   RKF-RIL-018__m00__T1-a__20190227__e013459.nii       True           RIL
# 48   RKF-RIL-019__m00__T1-a__20190409__e013550.nii       True           RIL
# 49   RKF-RIL-020__m00__T1-a__20190410__e013552.nii       True           RIL
# 50   RKF-RIL-021__m00__T1-a__20190515__e013645.nii       True           RIL
# 51   RKF-RIL-022__m00__T1-a__20190528__e013678.nii       True           RIL
# 52   RKF-RIL-024__m00__T1-a__20190724__e013826.nii       True           RIL
# 53   RKF-RIL-025__m00__T1-a__20190607__e013707.nii       True           RIL
# 54   RKF-RIL-027__m00__T1-a__20190614__e014208.nii      False           RIL
# 55   RKF-RIL-028__m00__T1-a__20190726__e013839.nii       True           RIL
# 56   RKF-RIL-029__m00__T1-a__20190806__e013866.nii       True           RIL
# 57   RKF-RIL-031__m00__T1-a__20191016__e014066.nii      False           RIL
#
#     Subject_Num      ID_ADM
# 0             1   APE-792_1
# 1             5   APE-792_5
# 2             7   APE-792_7
# 3             9   APE-792_9
# 4            10  APE-792_10
# 5            11  APE-792_11
# 6            13  APE-792_13
# 7            16  APE-792_16
# 8            18  APE-792_18
# 9            20  APE-792_20
# 10           21  APE-792_21
# 11           22  APE-792_22
# 12           23  APE-792_23
# 13           26  APE-792_26
# 14           27  APE-792_27
# 15           33  APE-792_33
# 16           34  APE-792_34
# 17           35  APE-792_35
# 18           36  APE-792_36
# 19           39  APE-792_39
# 20           40  APE-792_40
# 21           46  APE-792_46
# 22           47  APE-792_47
# 23           50  APE-792_50
# 24           53  APE-792_53
# 25           55  APE-792_55
# 26           56  APE-792_56
# 27           58  APE-792_58
# 28           60  APE-792_60
# 29           62  APE-792_62
# 30           65  APE-792_65
# 31           66  APE-792_66
# 32           71  APE-792_71
# 33            1       RIL_1
# 34            2       RIL_2
# 35            3       RIL_3
# 36            5       RIL_5
# 37            7       RIL_7
# 38            8       RIL_8
# 39            9       RIL_9
# 40           10      RIL_10
# 41           11      RIL_11
# 42           12      RIL_12
# 43           13      RIL_13
# 44           14      RIL_14
# 45           15      RIL_15
# 46           17      RIL_17
# 47           18      RIL_18
# 48           19      RIL_19
# 49           20      RIL_20
# 50           21      RIL_21
# 51           22      RIL_22
# 52           24      RIL_24
# 53           25      RIL_25
# 54           27      RIL_27
# 55           28      RIL_28
# 56           29      RIL_29
# 57           31      RIL_31

# %%
all_data_base = all_data[all_data['timepoint'].isin(['base'])]

# %%
randy_db_subset.columns[randy_db_subset.columns.isin(all_data_base.columns)]
# Out:
# Index(['Subject_Label', 'ID_ADM'], dtype='object')

# %%
all_imaging_plasma = pd.merge(
all_data_base, randy_db_subset, how = 'outer'
    
)

# %%
all_imaging_plasma['has_plasma'] = all_imaging_plasma[['Ab40',
 'Ab42',
 'GFAP',
 'NFL',
 'pTau181',
 'pTau217',
 'pTau231']].notna().any(axis = 1)

# %%
all_imaging_plasma['old_has_FDG'] = all_imaging_plasma[FDG_columns].notna().any(axis = 1)

# %%
all_imaging_plasma = all_imaging_plasma[['ID_ADM', 'timepoint', 'Subject_ID', 'Subject', 'AGE', 'Gender',
       'Visit (ADM)', 'FileName:', 'FDG_output', 'MRI ReName', 'FS_output', 'Subject_Num',
       'has_plasma', 'old_has_FDG']]

# %%
all_imaging_plasma
# Out:
#         ID_ADM timepoint   Subject_ID      Subject                 AGE Gender  \
# 0    APE-792_1      base  APE-792-001  RKF-APE-001                  76      M
# 1   APE-792_10      base  APE-792-010  RKF-APE-010                  58      F
# 2   APE-792_11      base  APE-792-011  RKF-APE-011                  81      F
# 3   APE-792_13      base  APE-792-013  RKF-APE-013                  80      F
# 4   APE-792_16      base  APE-792-016  RKF-APE-016                  77      F
# 5   APE-792_18      base  APE-792-018  RKF-APE-018                  73      F
# 6   APE-792_20      base  APE-792-020  RKF-APE-020                  71      F
# 7   APE-792_22      base          NaN  RKF-APE-022                 UNK      O
# 8   APE-792_26      base  APE-792-026  RKF-APE-026  72 (DICOM says 74)      F
# 9   APE-792_27      base  APE-792-027  RKF-APE-027                  84      F
# 10  APE-792_33      base  APE-792-033  RKF-APE-033                  68      F
# 11  APE-792_34      base  APE-792-034  RKF-APE-034  82 (DICOM says 84)      F
# 12  APE-792_36      base  APE-792-036  RKF-APE-036                  79      F
# 13  APE-792_39      base          NaN  RKF-APE-039                 UNK      O
# 14  APE-792_46      base  APE-792-046  RKF-APE-046                  72      F
# 15  APE-792_47      base  APE-792-047  RKF-APE-047                  77      M
# 16   APE-792_5      base  APE-792-005  RKF-APE-005                  81      M
# 17  APE-792_50      base  APE-792-050  RKF-APE-050                  60      M
# 18  APE-792_53      base  APE-792-053  RKF-APE-053                  77      F
# 19  APE-792_56      base  APE-792-056  RKF-APE-056  79 (DICOM says 81)      F
# 20  APE-792_58      base  APE-792-058  RKF-APE-058                  78      M
# 21  APE-792_60      base          NaN  RKF-APE-060                 UNK      O
# 22  APE-792_62      base  APE-792-062  RKF-APE-062  74 (DICOM says 75)      M
# 23  APE-792_65      base          NaN  RKF-APE-065                  81      M
# 24  APE-792_66      base  APE-792-066  RKF-APE-066  75 (DICOM says 76)      M
# 25   APE-792_7      base  APE-792-007  RKF-APE-007                  67      F
# 26   APE-792_9      base          NaN  RKF-APE-009                  75      M
# 27       RIL_1      base      RIL-001  RKF-RIL-001                  60      F
# 28      RIL_10      base      RIL-010  RKF-RIL-010                  66      F
# 29      RIL_11      base      RIL-011  RKF-RIL-011                  86      F
# 30      RIL_12      base      RIL-012  RKF-RIL-012                  82      F
# 31      RIL_14      base      RIL-014  RKF-RIL-014                  77      M
# 32      RIL_15      base      RIL-015  RKF-RIL-015                  79      M
# 33      RIL_17      base          NaN  RKF-RIL-017                  76      F
# 34      RIL_18      base      RIL-018  RKF-RIL-018                  67      M
# 35      RIL_19      base      RIL-019  RKF-RIL-019                  88      F
# 36       RIL_2      base      RIL-002  RKF-RIL-002                  76      F
# 37      RIL_20      base      RIL-020  RKF-RIL-020                  81      F
# 38      RIL_22      base      RIL-022  RKF-RIL-022                  76      F
# 39      RIL_24      base          NaN  RKF-RIL-024                  59      F
# 40      RIL_25      base      RIL-025  RKF-RIL-025                  69      F
# 41      RIL_27      base      RIL-027  RKF-RIL-027                  75      F
# 42      RIL_28      base      RIL-028  RKF-RIL-028  77 (DICOM says 78)      M
# 43      RIL_29      base      RIL-029  RKF-RIL-029                  74      F
# 44       RIL_3      base      RIL-003  RKF-RIL-003                  77      M
# 45      RIL_31      base      RIL-031  RKF-RIL-031  72 (DICOM says 73)      M
# 46       RIL_5      base          NaN  RKF-RIL-005                 UNK      O
# 47       RIL_7      base      RIL-007  RKF-RIL-007                  80      M
# 48       RIL_8      base      RIL-008  RKF-RIL-008                  71      M
# 49       RIL_9      base      RIL-009  RKF-RIL-009                  74      M
# 50  APE-792_21       NaN          NaN  RKF-APE-021                 UNK      O
# 51  APE-792_23       NaN          NaN  RKF-APE-023                 UNK      O
# 52  APE-792_35       NaN          NaN  RKF-APE-035                 UNK      O
# 53  APE-792_40       NaN          NaN  RKF-APE-040                 UNK      O
# 54  APE-792_55       NaN          NaN  RKF-APE-055                  81      M
# 55  APE-792_71       NaN          NaN  RKF-APE-071                  69      M
# 56      RIL_13       NaN          NaN  RKF-RIL-013                  70      M
# 57      RIL_21       NaN          NaN  RKF-RIL-021                 UNK      O
#
#    Visit (ADM)                                          FileName:  FDG_output  \
# 0          m00  n2a_sUR_i_n2a_rADNI_APE_792_201A__static-FDG__...        True
# 1          m00  n2a_sUR_i_n2a_rADNI_APE_792_210A__static-FDG__...        True
# 2          m00  n2a_sUR_i_n2a_rADNI_APE_792_211A__static-FDG__...        True
# 3          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_213A__dyn-FDG_0...        True
# 4          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_216A__dyn-FDG_0...        True
# 5          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_218A__dyn-FDG_0...        True
# 6          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_220A__dyn-FDG_0...        True
# 7          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-FDG_0...        True
# 8          m00  sUR_i_n2a_rADNI_mc_APE-792-226A__dyn-FDG_00001...        True
# 9          m00  sUR_i_n2a_rADNI_mc_APE-792-227A__dyn-FDG_00001...        True
# 10         m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_233A__dyn-FDG_0...        True
# 11         m00  i_n2a_sUR_rADNI_mc_APE_792_234a_nifti_4frame_0...        True
# 12         m00  i_n2a_sUR_rADNI_mc_APE_792_236A_nifti_4frame_0...        True
# 13         m00  i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4frame_0...        True
# 14         m00  i_n2a_sUR_rADNI_mc_APE_792_246A_nifti_4frame_0...        True
# 15         m00  i_n2a_sUR_rADNI_mc_APE_792_247a_nifti_4frame_0...        True
# 16         m00  n2a_sUR_i_n2a_rADNI_APE_792_205A__static-FDG__...        True
# 17         m00  i_n2a_sUR_rADNI_mc_APE-792-250a_frame1alignedt...        True
# 18         m00  i_n2a_sUR_rADNI_mc_APE_792_253a_nifti_4frame_0...        True
# 19         m00  i_n2a_sUR_rADNI_mc_APE_792_256A_multiframe_000...        True
# 20         m00  i_n2a_sUR_rADNI_mc_APE_792_258A_multiframe_000...        True
# 21         m00  i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe_000...        True
# 22         m00  i_n2a_sUR_rADNI_mc_APE_792_262A_multiframe_000...        True
# 23         m00  i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_0000...        True
# 24         m00  i_n2a_sUR_rADNI_mc_APE_792_266A_mutiframe_0000...        True
# 25         m00  sUR_i_n2a_rADNI_APE_792_207A_frame1__nmsks.sn.img        True
# 26         m00  n2a_sUR_i_n2a_rADNI_APE_792_209A__static-FDG__...        True
# 27         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2001A_multiframe_00...        True
# 28         m00  i_n2a_sUR_rADNI_mc_uo_RIL-1010A_multiframe_000...        True
# 29         m00  i_n2a_sUR_rADNI_mc_uo_RIL-1011A_multiframe_000...        True
# 30         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2012A_multiframe_00...        True
# 31         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2014A_multiframe_00...        True
# 32         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2015A_multiframe_00...        True
# 33         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multiframe_0...        True
# 34         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2018A_multiframe_0...        True
# 35         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2019A_multiframe_00...        True
# 36         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2002A_multiframe_00...        True
# 37         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2020A_multiframe_00...        True
# 38         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2022A_multiframe_00...        True
# 39         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multifram...        True
# 40         m00  i_n2a_sUR_rADNI_meano_RIL_S_2025A_multiframe_0...        True
# 41         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2027A_multiframe_00...        True
# 42         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL-2028A_multiframe_...        True
# 43         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2029A_multifram...        True
# 44         NaN  i_n2a_sUR_rADNI_mc_o_RIL_S_2003A_multiframe_00...        True
# 45         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL-031A_multiframe_0...        True
# 46         NaN  i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multiframe_0...        True
# 47        m00x  i_n2a_sUR_rADNI_mc_uo_RIL_S_2007A_multiframe_0...        True
# 48         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2008A_mutiframe_00...        True
# 49        m00x  i_n2a_sUR_rADNI_mc_o_RIL_S_1009A_mutiframe_000...        True
# 50         m00  i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4frame_0...        True
# 51         m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-FDG_0...        True
# 52         m00  i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4frame_0...        True
# 53         m00  i_n2a_sUR_rADNI_mc_APE_792_240a_multiframe_000...        True
# 54         NaN                                                NaN       False
# 55         m00  i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe_000...        True
# 56         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multiframe_0...        True
# 57         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multiframe_...        True
#
#                                         MRI ReName  FS_output  Subject_Num  \
# 0    RKF-APE-001__m00__T1-a__20131125__e010542.nii       True            1
# 1    RKF-APE-010__m00__T1-a__20140530__e010753.nii       True           10
# 2    RKF-APE-011__m00__T1-a__20140527__e010746.nii       True           11
# 3    RKF-APE-013__m00__T1-a__20140630__e010796.nii       True           13
# 4    RKF-APE-016__m00__T1-a__20141121__n115548.nii       True           16
# 5    RKF-APE-018__m00__T1-a__20141125__n102556.nii       True           18
# 6    RKF-APE-020__m00__T1-a__20141126__n112426.nii       True           20
# 7    RKF-APE-022__m00__T1-a__20150224__n123534.nii       True           22
# 8                                          PENDING      False           26
# 9    RKF-APE-027__m00__T1-a__2015xxxx__saNiFTI.nii       True           27
# 10   RKF-APE-033__m00__T1-a__2015xxxx__saNiFTI.nii       True           33
# 11   RKF-APE-034__m00__T1-a__2015xxxx__saNiFTI.nii       True           34
# 12   RKF-APE-036__m00__T1-a__2016xxxx__saNiFTI.nii       True           36
# 13   RKF-APE-039__m00__T1-a__2015xxxx__saNiFTI.nii       True           39
# 14   RKF-APE-046__m00__T1-a__20150928__e011544.nii       True           46
# 15   RKF-APE-047__m00__T1-a__20150824__e011493.nii      False           47
# 16   RKF-APE-005__m00__T1-a__20140428__e010707.nii       True            5
# 17   RKF-APE-050__m00__T1-a__20151008__e011560.nii       True           50
# 18   RKF-APE-053__m00__T1-a__2015xxxx__saNiFTI.nii       True           53
# 19                                        PENDING?      False           56
# 20   RKF-APE-058__m00__T1-a__20161011__e011842.nii       True           58
# 21                                        PENDING?      False           60
# 22   RKF-APE-062__m00__T1-a__20170214__e012034.nii       True           62
# 23   RKF-APE-065__m00__T1-a__20170517__e012169.nii       True           65
# 24                                        PENDING?      False           66
# 25   RKF-APE-007__m00__T1-a__20140418__e010695.nii       True            7
# 26   RKF-APE-009__m00__T1-a__20140520__e010737.nii       True            9
# 27   RKF-RIL-001__m00__T1-a__20180518__e012890.nii      False            1
# 28   RKF-RIL-010__m00__T1-a__20181109__e013221.nii       True           10
# 29   RKF-RIL-011__m00__T1-a__20181108__e013219.nii       True           11
# 30   RKF-RIL-012__m00__T1-a__20181218__e013304.nii       True           12
# 31   RKF-RIL-014__m00__T1-a__20181221__e013312.nii       True           14
# 32   RKF-RIL-015__m00__T1-a__20190326__e013512.nii       True           15
# 33   RKF-RIL-017__m00__T1-a__20190225__e013451.nii       True           17
# 34   RKF-RIL-018__m00__T1-a__20190227__e013459.nii       True           18
# 35   RKF-RIL-019__m00__T1-a__20190409__e013550.nii       True           19
# 36   RKF-RIL-002__m00__T1-a__20180615__e012940.nii      False            2
# 37   RKF-RIL-020__m00__T1-a__20190410__e013552.nii       True           20
# 38   RKF-RIL-022__m00__T1-a__20190528__e013678.nii       True           22
# 39   RKF-RIL-024__m00__T1-a__20190724__e013826.nii       True           24
# 40   RKF-RIL-025__m00__T1-a__20190607__e013707.nii       True           25
# 41   RKF-RIL-027__m00__T1-a__20190614__e014208.nii      False           27
# 42   RKF-RIL-028__m00__T1-a__20190726__e013839.nii       True           28
# 43   RKF-RIL-029__m00__T1-a__20190806__e013866.nii       True           29
# 44   RKF-RIL-003__m06__T1-c__20190304__e013465.nii      False            3
# 45   RKF-RIL-031__m00__T1-a__20191016__e014066.nii      False           31
# 46                                        PENDING?      False            5
# 47  RKF-RIL-007__m00x__T1-b__20181211__e013282.nii       True            7
# 48   RKF-RIL-008__m00__T1-a__20181005__e013155.nii       True            8
# 49   RKF-RIL-009__m00__T1-a__20181016__e013178.nii      False            9
# 50                                        PENDING?      False           21
# 51   RKF-APE-023__m00__T1-a__20150310__n114941.nii       True           23
# 52   RKF-APE-035__m00__T1-a__2015xxxx__saNiFTI.nii       True           35
# 53                                        PENDING?      False           40
# 54                                             NaN      False           55
# 55   RKF-APE-071__m00__T1-a__20180720__e012994.nii       True           71
# 56   RKF-RIL-013__m00__T1-a__20190129__e013380.nii       True           13
# 57   RKF-RIL-021__m00__T1-a__20190515__e013645.nii       True           21
#
#     has_plasma  old_has_FDG
# 0         True         True
# 1         True         True
# 2         True         True
# 3         True         True
# 4         True         True
# 5         True         True
# 6         True         True
# 7         True        False
# 8         True         True
# 9         True         True
# 10        True         True
# 11        True         True
# 12        True         True
# 13        True        False
# 14        True         True
# 15        True         True
# 16        True         True
# 17        True         True
# 18        True         True
# 19        True         True
# 20       False         True
# 21        True        False
# 22        True         True
# 23        True        False
# 24        True         True
# 25        True         True
# 26        True        False
# 27        True         True
# 28        True         True
# 29        True         True
# 30        True         True
# 31        True         True
# 32        True         True
# 33        True        False
# 34        True         True
# 35        True         True
# 36        True         True
# 37       False         True
# 38       False         True
# 39        True        False
# 40        True         True
# 41        True         True
# 42        True         True
# 43        True         True
# 44        True         True
# 45        True         True
# 46        True        False
# 47        True         True
# 48        True         True
# 49        True         True
# 50       False        False
# 51       False        False
# 52       False        False
# 53       False        False
# 54       False        False
# 55       False        False
# 56       False        False
# 57       False        False

# %%
all_imaging_plasma[['FDG_output', 'has_plasma','old_has_FDG'  ]].value_counts().sort_index()
# Out:
# FDG_output  has_plasma  old_has_FDG
# False       False       False           1
# True        False       False           7
#                         True            3
#             True        False           8
#                         True           39
# dtype: int64

# %%
all_imaging_plasma[[ 'has_plasma','old_has_FDG', 'FS_output'  ]].value_counts().sort_index()
# Out:
# has_plasma  old_has_FDG  FS_output
# False       False        False         3
#                          True          5
#             True         True          3
# True        False        False         2
#                          True          6
#             True         False        10
#                          True         29
# dtype: int64

# %%
all_imaging_plasma
# Out:
#         ID_ADM timepoint   Subject_ID      Subject                 AGE Gender  \
# 0    APE-792_1      base  APE-792-001  RKF-APE-001                  76      M
# 1   APE-792_10      base  APE-792-010  RKF-APE-010                  58      F
# 2   APE-792_11      base  APE-792-011  RKF-APE-011                  81      F
# 3   APE-792_13      base  APE-792-013  RKF-APE-013                  80      F
# 4   APE-792_16      base  APE-792-016  RKF-APE-016                  77      F
# 5   APE-792_18      base  APE-792-018  RKF-APE-018                  73      F
# 6   APE-792_20      base  APE-792-020  RKF-APE-020                  71      F
# 7   APE-792_22      base          NaN  RKF-APE-022                 UNK      O
# 8   APE-792_26      base  APE-792-026  RKF-APE-026  72 (DICOM says 74)      F
# 9   APE-792_27      base  APE-792-027  RKF-APE-027                  84      F
# 10  APE-792_33      base  APE-792-033  RKF-APE-033                  68      F
# 11  APE-792_34      base  APE-792-034  RKF-APE-034  82 (DICOM says 84)      F
# 12  APE-792_36      base  APE-792-036  RKF-APE-036                  79      F
# 13  APE-792_39      base          NaN  RKF-APE-039                 UNK      O
# 14  APE-792_46      base  APE-792-046  RKF-APE-046                  72      F
# 15  APE-792_47      base  APE-792-047  RKF-APE-047                  77      M
# 16   APE-792_5      base  APE-792-005  RKF-APE-005                  81      M
# 17  APE-792_50      base  APE-792-050  RKF-APE-050                  60      M
# 18  APE-792_53      base  APE-792-053  RKF-APE-053                  77      F
# 19  APE-792_56      base  APE-792-056  RKF-APE-056  79 (DICOM says 81)      F
# 20  APE-792_58      base  APE-792-058  RKF-APE-058                  78      M
# 21  APE-792_60      base          NaN  RKF-APE-060                 UNK      O
# 22  APE-792_62      base  APE-792-062  RKF-APE-062  74 (DICOM says 75)      M
# 23  APE-792_65      base          NaN  RKF-APE-065                  81      M
# 24  APE-792_66      base  APE-792-066  RKF-APE-066  75 (DICOM says 76)      M
# 25   APE-792_7      base  APE-792-007  RKF-APE-007                  67      F
# 26   APE-792_9      base          NaN  RKF-APE-009                  75      M
# 27       RIL_1      base      RIL-001  RKF-RIL-001                  60      F
# 28      RIL_10      base      RIL-010  RKF-RIL-010                  66      F
# 29      RIL_11      base      RIL-011  RKF-RIL-011                  86      F
# 30      RIL_12      base      RIL-012  RKF-RIL-012                  82      F
# 31      RIL_14      base      RIL-014  RKF-RIL-014                  77      M
# 32      RIL_15      base      RIL-015  RKF-RIL-015                  79      M
# 33      RIL_17      base          NaN  RKF-RIL-017                  76      F
# 34      RIL_18      base      RIL-018  RKF-RIL-018                  67      M
# 35      RIL_19      base      RIL-019  RKF-RIL-019                  88      F
# 36       RIL_2      base      RIL-002  RKF-RIL-002                  76      F
# 37      RIL_20      base      RIL-020  RKF-RIL-020                  81      F
# 38      RIL_22      base      RIL-022  RKF-RIL-022                  76      F
# 39      RIL_24      base          NaN  RKF-RIL-024                  59      F
# 40      RIL_25      base      RIL-025  RKF-RIL-025                  69      F
# 41      RIL_27      base      RIL-027  RKF-RIL-027                  75      F
# 42      RIL_28      base      RIL-028  RKF-RIL-028  77 (DICOM says 78)      M
# 43      RIL_29      base      RIL-029  RKF-RIL-029                  74      F
# 44       RIL_3      base      RIL-003  RKF-RIL-003                  77      M
# 45      RIL_31      base      RIL-031  RKF-RIL-031  72 (DICOM says 73)      M
# 46       RIL_5      base          NaN  RKF-RIL-005                 UNK      O
# 47       RIL_7      base      RIL-007  RKF-RIL-007                  80      M
# 48       RIL_8      base      RIL-008  RKF-RIL-008                  71      M
# 49       RIL_9      base      RIL-009  RKF-RIL-009                  74      M
# 50  APE-792_21       NaN          NaN  RKF-APE-021                 UNK      O
# 51  APE-792_23       NaN          NaN  RKF-APE-023                 UNK      O
# 52  APE-792_35       NaN          NaN  RKF-APE-035                 UNK      O
# 53  APE-792_40       NaN          NaN  RKF-APE-040                 UNK      O
# 54  APE-792_55       NaN          NaN  RKF-APE-055                  81      M
# 55  APE-792_71       NaN          NaN  RKF-APE-071                  69      M
# 56      RIL_13       NaN          NaN  RKF-RIL-013                  70      M
# 57      RIL_21       NaN          NaN  RKF-RIL-021                 UNK      O
#
#    Visit (ADM)                                          FileName:  FDG_output  \
# 0          m00  n2a_sUR_i_n2a_rADNI_APE_792_201A__static-FDG__...        True
# 1          m00  n2a_sUR_i_n2a_rADNI_APE_792_210A__static-FDG__...        True
# 2          m00  n2a_sUR_i_n2a_rADNI_APE_792_211A__static-FDG__...        True
# 3          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_213A__dyn-FDG_0...        True
# 4          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_216A__dyn-FDG_0...        True
# 5          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_218A__dyn-FDG_0...        True
# 6          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_220A__dyn-FDG_0...        True
# 7          m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-FDG_0...        True
# 8          m00  sUR_i_n2a_rADNI_mc_APE-792-226A__dyn-FDG_00001...        True
# 9          m00  sUR_i_n2a_rADNI_mc_APE-792-227A__dyn-FDG_00001...        True
# 10         m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_233A__dyn-FDG_0...        True
# 11         m00  i_n2a_sUR_rADNI_mc_APE_792_234a_nifti_4frame_0...        True
# 12         m00  i_n2a_sUR_rADNI_mc_APE_792_236A_nifti_4frame_0...        True
# 13         m00  i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4frame_0...        True
# 14         m00  i_n2a_sUR_rADNI_mc_APE_792_246A_nifti_4frame_0...        True
# 15         m00  i_n2a_sUR_rADNI_mc_APE_792_247a_nifti_4frame_0...        True
# 16         m00  n2a_sUR_i_n2a_rADNI_APE_792_205A__static-FDG__...        True
# 17         m00  i_n2a_sUR_rADNI_mc_APE-792-250a_frame1alignedt...        True
# 18         m00  i_n2a_sUR_rADNI_mc_APE_792_253a_nifti_4frame_0...        True
# 19         m00  i_n2a_sUR_rADNI_mc_APE_792_256A_multiframe_000...        True
# 20         m00  i_n2a_sUR_rADNI_mc_APE_792_258A_multiframe_000...        True
# 21         m00  i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe_000...        True
# 22         m00  i_n2a_sUR_rADNI_mc_APE_792_262A_multiframe_000...        True
# 23         m00  i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_0000...        True
# 24         m00  i_n2a_sUR_rADNI_mc_APE_792_266A_mutiframe_0000...        True
# 25         m00  sUR_i_n2a_rADNI_APE_792_207A_frame1__nmsks.sn.img        True
# 26         m00  n2a_sUR_i_n2a_rADNI_APE_792_209A__static-FDG__...        True
# 27         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2001A_multiframe_00...        True
# 28         m00  i_n2a_sUR_rADNI_mc_uo_RIL-1010A_multiframe_000...        True
# 29         m00  i_n2a_sUR_rADNI_mc_uo_RIL-1011A_multiframe_000...        True
# 30         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2012A_multiframe_00...        True
# 31         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2014A_multiframe_00...        True
# 32         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2015A_multiframe_00...        True
# 33         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multiframe_0...        True
# 34         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2018A_multiframe_0...        True
# 35         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2019A_multiframe_00...        True
# 36         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2002A_multiframe_00...        True
# 37         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2020A_multiframe_00...        True
# 38         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2022A_multiframe_00...        True
# 39         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multifram...        True
# 40         m00  i_n2a_sUR_rADNI_meano_RIL_S_2025A_multiframe_0...        True
# 41         m00  i_n2a_sUR_rADNI_mc_o_RIL_S_2027A_multiframe_00...        True
# 42         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL-2028A_multiframe_...        True
# 43         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2029A_multifram...        True
# 44         NaN  i_n2a_sUR_rADNI_mc_o_RIL_S_2003A_multiframe_00...        True
# 45         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL-031A_multiframe_0...        True
# 46         NaN  i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multiframe_0...        True
# 47        m00x  i_n2a_sUR_rADNI_mc_uo_RIL_S_2007A_multiframe_0...        True
# 48         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2008A_mutiframe_00...        True
# 49        m00x  i_n2a_sUR_rADNI_mc_o_RIL_S_1009A_mutiframe_000...        True
# 50         m00  i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4frame_0...        True
# 51         m00  n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-FDG_0...        True
# 52         m00  i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4frame_0...        True
# 53         m00  i_n2a_sUR_rADNI_mc_APE_792_240a_multiframe_000...        True
# 54         NaN                                                NaN       False
# 55         m00  i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe_000...        True
# 56         m00  i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multiframe_0...        True
# 57         m00  i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multiframe_...        True
#
#                                         MRI ReName  FS_output  Subject_Num  \
# 0    RKF-APE-001__m00__T1-a__20131125__e010542.nii       True            1
# 1    RKF-APE-010__m00__T1-a__20140530__e010753.nii       True           10
# 2    RKF-APE-011__m00__T1-a__20140527__e010746.nii       True           11
# 3    RKF-APE-013__m00__T1-a__20140630__e010796.nii       True           13
# 4    RKF-APE-016__m00__T1-a__20141121__n115548.nii       True           16
# 5    RKF-APE-018__m00__T1-a__20141125__n102556.nii       True           18
# 6    RKF-APE-020__m00__T1-a__20141126__n112426.nii       True           20
# 7    RKF-APE-022__m00__T1-a__20150224__n123534.nii       True           22
# 8                                          PENDING      False           26
# 9    RKF-APE-027__m00__T1-a__2015xxxx__saNiFTI.nii       True           27
# 10   RKF-APE-033__m00__T1-a__2015xxxx__saNiFTI.nii       True           33
# 11   RKF-APE-034__m00__T1-a__2015xxxx__saNiFTI.nii       True           34
# 12   RKF-APE-036__m00__T1-a__2016xxxx__saNiFTI.nii       True           36
# 13   RKF-APE-039__m00__T1-a__2015xxxx__saNiFTI.nii       True           39
# 14   RKF-APE-046__m00__T1-a__20150928__e011544.nii       True           46
# 15   RKF-APE-047__m00__T1-a__20150824__e011493.nii      False           47
# 16   RKF-APE-005__m00__T1-a__20140428__e010707.nii       True            5
# 17   RKF-APE-050__m00__T1-a__20151008__e011560.nii       True           50
# 18   RKF-APE-053__m00__T1-a__2015xxxx__saNiFTI.nii       True           53
# 19                                        PENDING?      False           56
# 20   RKF-APE-058__m00__T1-a__20161011__e011842.nii       True           58
# 21                                        PENDING?      False           60
# 22   RKF-APE-062__m00__T1-a__20170214__e012034.nii       True           62
# 23   RKF-APE-065__m00__T1-a__20170517__e012169.nii       True           65
# 24                                        PENDING?      False           66
# 25   RKF-APE-007__m00__T1-a__20140418__e010695.nii       True            7
# 26   RKF-APE-009__m00__T1-a__20140520__e010737.nii       True            9
# 27   RKF-RIL-001__m00__T1-a__20180518__e012890.nii      False            1
# 28   RKF-RIL-010__m00__T1-a__20181109__e013221.nii       True           10
# 29   RKF-RIL-011__m00__T1-a__20181108__e013219.nii       True           11
# 30   RKF-RIL-012__m00__T1-a__20181218__e013304.nii       True           12
# 31   RKF-RIL-014__m00__T1-a__20181221__e013312.nii       True           14
# 32   RKF-RIL-015__m00__T1-a__20190326__e013512.nii       True           15
# 33   RKF-RIL-017__m00__T1-a__20190225__e013451.nii       True           17
# 34   RKF-RIL-018__m00__T1-a__20190227__e013459.nii       True           18
# 35   RKF-RIL-019__m00__T1-a__20190409__e013550.nii       True           19
# 36   RKF-RIL-002__m00__T1-a__20180615__e012940.nii      False            2
# 37   RKF-RIL-020__m00__T1-a__20190410__e013552.nii       True           20
# 38   RKF-RIL-022__m00__T1-a__20190528__e013678.nii       True           22
# 39   RKF-RIL-024__m00__T1-a__20190724__e013826.nii       True           24
# 40   RKF-RIL-025__m00__T1-a__20190607__e013707.nii       True           25
# 41   RKF-RIL-027__m00__T1-a__20190614__e014208.nii      False           27
# 42   RKF-RIL-028__m00__T1-a__20190726__e013839.nii       True           28
# 43   RKF-RIL-029__m00__T1-a__20190806__e013866.nii       True           29
# 44   RKF-RIL-003__m06__T1-c__20190304__e013465.nii      False            3
# 45   RKF-RIL-031__m00__T1-a__20191016__e014066.nii      False           31
# 46                                        PENDING?      False            5
# 47  RKF-RIL-007__m00x__T1-b__20181211__e013282.nii       True            7
# 48   RKF-RIL-008__m00__T1-a__20181005__e013155.nii       True            8
# 49   RKF-RIL-009__m00__T1-a__20181016__e013178.nii      False            9
# 50                                        PENDING?      False           21
# 51   RKF-APE-023__m00__T1-a__20150310__n114941.nii       True           23
# 52   RKF-APE-035__m00__T1-a__2015xxxx__saNiFTI.nii       True           35
# 53                                        PENDING?      False           40
# 54                                             NaN      False           55
# 55   RKF-APE-071__m00__T1-a__20180720__e012994.nii       True           71
# 56   RKF-RIL-013__m00__T1-a__20190129__e013380.nii       True           13
# 57   RKF-RIL-021__m00__T1-a__20190515__e013645.nii       True           21
#
#     has_plasma  old_has_FDG
# 0         True         True
# 1         True         True
# 2         True         True
# 3         True         True
# 4         True         True
# 5         True         True
# 6         True         True
# 7         True        False
# 8         True         True
# 9         True         True
# 10        True         True
# 11        True         True
# 12        True         True
# 13        True        False
# 14        True         True
# 15        True         True
# 16        True         True
# 17        True         True
# 18        True         True
# 19        True         True
# 20       False         True
# 21        True        False
# 22        True         True
# 23        True        False
# 24        True         True
# 25        True         True
# 26        True        False
# 27        True         True
# 28        True         True
# 29        True         True
# 30        True         True
# 31        True         True
# 32        True         True
# 33        True        False
# 34        True         True
# 35        True         True
# 36        True         True
# 37       False         True
# 38       False         True
# 39        True        False
# 40        True         True
# 41        True         True
# 42        True         True
# 43        True         True
# 44        True         True
# 45        True         True
# 46        True        False
# 47        True         True
# 48        True         True
# 49        True         True
# 50       False        False
# 51       False        False
# 52       False        False
# 53       False        False
# 54       False        False
# 55       False        False
# 56       False        False
# 57       False        False

# %% [markdown]
# # Main Comparisons

# %% [markdown]
# new FDG data that has plasma that we'll add to dataset:
# APE-792_22
#     - originally did not have demographics
#     - 67 yo F
#     - 1/3 backfills that required FDG sampling
#     - listed in X:\CustomerStudies\Rockefeller\RIL_n3_FDG-GM-Sampling_072924.xlsx
# APE-792_65
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
# APE-792_9
#     - non-completer
#     - will be added
#     - 1/3 backfills that required FDG sampling
#     - listed in X:\CustomerStudies\Rockefeller\RIL_n3_FDG-GM-Sampling_072924.xlsx
# RIL_17
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
# RIL_24
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
#
#
# new FDG data that has plasma but that can't be added:
# APE-792_39
#     - originally did not have demographics
#     - was excluded by neuropsychological testing as not meeting criteria for AD
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
# APE-792_60
#     - never received a T1. Randy says: 'I have no record of an acquisition date. I did ask multiple times 2019/2020 for this.'
#     - originally did not have demographics
#     - 84yo F
# RIL_5
#     - 'completer'
#     - originally did not have demographics
#     - 64 yo F
#     - never received T1. Randy says 'I have no record of an acquisition date. I did ask multiple times 2019/2020 for this.'
#
#
# Additional ppts Randy was looking at adding (no plasma):
#
# APE_23
#     - originally did not have demographics
#     -  was excluded because he had a more Lewy Body Disease pattern. He is male and age 70yo
#     - 1/3 of 'backfills' that completed without issue
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
# APE_35
#     - originally did not have demographics
#     -  was excluded because Dawn said the FDG Pet was not characteristic of AD. Female and 75yo
#     - 1/3 of 'backfills' that completed without issue
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
# APE_71
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
# RIL_13
#  - non-completer
#  - Randy said  'appears to have an issue in the R. Inf. Frontal, but the FDG Co-registers just fine.  I’ll be curious how CI treats this'
#  - 1/3 backfills that required FDG sampling
#  - listed in X:\CustomerStudies\Rockefeller\RIL_n3_FDG-GM-Sampling_072924.xlsx
# RIL_21
#     - originally did not have demographics
#     - was excluded as not a characteristic pattern of AD on FDG PET. Female and 72 yo.
#     - 1/3 of 'backfills' that completed without issue
#     - Listed in the X:\CustomerStudies\Rockefeller\RIL_n8_FDG-GM-Sampling_072224.xlsx
#
#
# Other subjects Randy's mentioned:
#  The two subjects that exceeded time limit did so again. (APE-046; RIL-009). Those two did complete the protocol, so some sort of time-extension to the hardcode might be needed.
# APE-062 (also a “completer”) did finish CI this time (had had an issue with “rh.hippoSfLabels-T1.v10.FSvoxelSpace.mgz”, but that seemed resolved this time around).

# %%
# new FDG data that has plasma
print(all_imaging_plasma.loc[(all_imaging_plasma['has_plasma']==True) & (all_imaging_plasma['FDG_output']==True) & (all_imaging_plasma['old_has_FDG']==False), 'ID_ADM'].to_list())
print(all_imaging_plasma.loc[(all_imaging_plasma['has_plasma']==True) & (all_imaging_plasma['FDG_output']==True) & (all_imaging_plasma['old_has_FDG']==False), 'FileName:'].to_list())

all_imaging_plasma.loc[(all_imaging_plasma['has_plasma']==True) & (all_imaging_plasma['old_has_FDG']==False)]
# Out:
# ['APE-792_22', 'APE-792_39', 'APE-792_60', 'APE-792_65', 'APE-792_9', 'RIL_17', 'RIL_24', 'RIL_5']
# ['n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-FDG_00001__nmsks.sn.img', 'i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4frame_00001__nmsks.sn.img', 'i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe_00001__nmsks.sn.img', 'i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_00001__nmsks.sn.img', 'n2a_sUR_i_n2a_rADNI_APE_792_209A__static-FDG__nmsks.sn.img', 'i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multiframe_00001__nmsks.sn.img', 'i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multiframe_00001__nmsks.sn.img', 'i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multiframe_00001__nmsks.sn.img']
#         ID_ADM timepoint Subject_ID      Subject  AGE Gender Visit (ADM)  \
# 7   APE-792_22      base        NaN  RKF-APE-022  UNK      O         m00
# 13  APE-792_39      base        NaN  RKF-APE-039  UNK      O         m00
# 21  APE-792_60      base        NaN  RKF-APE-060  UNK      O         m00
# 23  APE-792_65      base        NaN  RKF-APE-065   81      M         m00
# 26   APE-792_9      base        NaN  RKF-APE-009   75      M         m00
# 33      RIL_17      base        NaN  RKF-RIL-017   76      F         m00
# 39      RIL_24      base        NaN  RKF-RIL-024   59      F         m00
# 46       RIL_5      base        NaN  RKF-RIL-005  UNK      O         NaN
#
#                                             FileName:  FDG_output  \
# 7   n2a_sUR_i_n2a_rADNI_mc_APE_792_222A__dyn-FDG_0...        True
# 13  i_n2a_sUR_rADNI_mc_APE_792_239a_nifti_4frame_0...        True
# 21  i_n2a_sUR_rADNI_mc_AEP_792_260A_multiframe_000...        True
# 23  i_n2a_sUR_rADNI_mc_APE_792_265A_mutiframe_0000...        True
# 26  n2a_sUR_i_n2a_rADNI_APE_792_209A__static-FDG__...        True
# 33  i_n2a_sUR_rADNI_mc_uo_RIL_S_2017A_multiframe_0...        True
# 39  i_n2a_sUR_rADNI_mc_o_RKF-RIL_S_2024A_multifram...        True
# 46  i_n2a_sUR_rADNI_mc_uo_RIL_S_2005A_multiframe_0...        True
#
#                                        MRI ReName  FS_output  Subject_Num  \
# 7   RKF-APE-022__m00__T1-a__20150224__n123534.nii       True           22
# 13  RKF-APE-039__m00__T1-a__2015xxxx__saNiFTI.nii       True           39
# 21                                       PENDING?      False           60
# 23  RKF-APE-065__m00__T1-a__20170517__e012169.nii       True           65
# 26  RKF-APE-009__m00__T1-a__20140520__e010737.nii       True            9
# 33  RKF-RIL-017__m00__T1-a__20190225__e013451.nii       True           17
# 39  RKF-RIL-024__m00__T1-a__20190724__e013826.nii       True           24
# 46                                       PENDING?      False            5
#
#     has_plasma  old_has_FDG
# 7         True        False
# 13        True        False
# 21        True        False
# 23        True        False
# 26        True        False
# 33        True        False
# 39        True        False
# 46        True        False

# %%
# old FDG data that doesn't have plasma

print(all_imaging_plasma.loc[(all_imaging_plasma['has_plasma']==False) & (all_imaging_plasma['FDG_output']==True) & (all_imaging_plasma['old_has_FDG']==True), 'ID_ADM'].to_list())
all_imaging_plasma.loc[(all_imaging_plasma['has_plasma']==False) & (all_imaging_plasma['FDG_output']==True) & (all_imaging_plasma['old_has_FDG']==True)]
# Out:
# ['APE-792_58', 'RIL_20', 'RIL_22']
#         ID_ADM timepoint   Subject_ID      Subject AGE Gender Visit (ADM)  \
# 20  APE-792_58      base  APE-792-058  RKF-APE-058  78      M         m00
# 37      RIL_20      base      RIL-020  RKF-RIL-020  81      F         m00
# 38      RIL_22      base      RIL-022  RKF-RIL-022  76      F         m00
#
#                                             FileName:  FDG_output  \
# 20  i_n2a_sUR_rADNI_mc_APE_792_258A_multiframe_000...        True
# 37  i_n2a_sUR_rADNI_mc_o_RIL_S_2020A_multiframe_00...        True
# 38  i_n2a_sUR_rADNI_mc_o_RIL_S_2022A_multiframe_00...        True
#
#                                        MRI ReName  FS_output  Subject_Num  \
# 20  RKF-APE-058__m00__T1-a__20161011__e011842.nii       True           58
# 37  RKF-RIL-020__m00__T1-a__20190410__e013552.nii       True           20
# 38  RKF-RIL-022__m00__T1-a__20190528__e013678.nii       True           22
#
#     has_plasma  old_has_FDG
# 20       False         True
# 37       False         True
# 38       False         True

# %%
# new FDG data that doesn't have plasma
print(all_imaging_plasma.loc[(all_imaging_plasma['has_plasma']==False) & (all_imaging_plasma['FDG_output']==True) & (all_imaging_plasma['old_has_FDG']==False), 'ID_ADM'].to_list())
all_imaging_plasma.loc[(all_imaging_plasma['has_plasma']==False) & (all_imaging_plasma['FDG_output']==True) & (all_imaging_plasma['old_has_FDG']==False)]
# Out:
# ['APE-792_21', 'APE-792_23', 'APE-792_35', 'APE-792_40', 'APE-792_71', 'RIL_13', 'RIL_21']
#         ID_ADM timepoint Subject_ID      Subject  AGE Gender Visit (ADM)  \
# 50  APE-792_21       NaN        NaN  RKF-APE-021  UNK      O         m00
# 51  APE-792_23       NaN        NaN  RKF-APE-023  UNK      O         m00
# 52  APE-792_35       NaN        NaN  RKF-APE-035  UNK      O         m00
# 53  APE-792_40       NaN        NaN  RKF-APE-040  UNK      O         m00
# 55  APE-792_71       NaN        NaN  RKF-APE-071   69      M         m00
# 56      RIL_13       NaN        NaN  RKF-RIL-013   70      M         m00
# 57      RIL_21       NaN        NaN  RKF-RIL-021  UNK      O         m00
#
#                                             FileName:  FDG_output  \
# 50  i_n2a_sUR_rADNI_mc_APE_792_221a_nifti_4frame_0...        True
# 51  n2a_sUR_i_n2a_rADNI_mc_APE_792_223A__dyn-FDG_0...        True
# 52  i_n2a_sUR_rADNI_mc_APE_792_235a_nifti_4frame_0...        True
# 53  i_n2a_sUR_rADNI_mc_APE_792_240a_multiframe_000...        True
# 55  i_n2a_sUR_rADNI_mc_APE_792_171A_multiframe_000...        True
# 56  i_n2a_sUR_rADNI_mc_uo_RIL_S_2013A_multiframe_0...        True
# 57  i_n2a_sUR_rADNI_mc_o_RKF-RIL_2021A_multiframe_...        True
#
#                                        MRI ReName  FS_output  Subject_Num  \
# 50                                       PENDING?      False           21
# 51  RKF-APE-023__m00__T1-a__20150310__n114941.nii       True           23
# 52  RKF-APE-035__m00__T1-a__2015xxxx__saNiFTI.nii       True           35
# 53                                       PENDING?      False           40
# 55  RKF-APE-071__m00__T1-a__20180720__e012994.nii       True           71
# 56  RKF-RIL-013__m00__T1-a__20190129__e013380.nii       True           13
# 57  RKF-RIL-021__m00__T1-a__20190515__e013645.nii       True           21
#
#     has_plasma  old_has_FDG
# 50       False        False
# 51       False        False
# 52       False        False
# 53       False        False
# 55       False        False
# 56       False        False
# 57       False        False
